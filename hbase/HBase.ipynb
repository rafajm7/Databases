# %% [markdown]
# # HBase

# %% [markdown]
# Con HBase vamos a simular un _clúster_ de varias máquinas con varios contenedores conectados. En el directorio `hbase` del repositorio git hay un script para ejecutar la instalación con `docker-compose`.
#
# Para conectarse al _clúster_ con un _shell_ de hbase, hay que ejecutar, desde una terminal el siguiente comando de docker:
#
# ```bash
# $ docker exec -ti hbase-regionserver hbase shell
# Base Shell; enter 'help<RETURN>' for list of supported commands.
# Type "exit<RETURN>" to leave the HBase Shell
# Version 1.2.7, rac57c51f7ad25e312b4275665d62b34a5945422f, Fri Sep  7 16:11:05 CDT 2018
#
# hbase(main):001:0>
# ```

# %% [markdown]
# Comenzamos instalando e importando la librería `happybase` y creado la conexión con el Thrift Server para poder manejar la base de datos desde python.

# %%
# !pip install happybase
# Out:
# Requirement already satisfied: happybase in /opt/conda/lib/python3.7/site-packages (1.2.0)
# Requirement already satisfied: thriftpy2>=0.4 in /opt/conda/lib/python3.7/site-packages (from happybase) (0.4.8)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from happybase) (1.12.0)
# Requirement already satisfied: ply<4.0,>=3.4 in /opt/conda/lib/python3.7/site-packages (from thriftpy2>=0.4->happybase) (3.11)

# %%
import happybase
from contextlib import contextmanager

HBASEHOST = 'hbase-thriftserver'

class Connection():
    
    def __init__(self, host):
        self.host = host
        self._genpool()
        
    def _genpool(self):
        self.pool = happybase.ConnectionPool(size=5, host=self.host)
    
    @contextmanager
    def connection(self):
        for _ in range(5): # Probar 5 veces a regenerar el pool
            for _ in range(5): # Probar 5 veces a conectar
                with self.pool.connection() as connection:
                    try:
                        connection.tables()
                        yield connection
                        return
                    except Exception as e:
                        pass
            self._genpool()
        raise Exception("HBase Connection Error")

# %%
hbasecon = Connection(HBASEHOST)

# %% [markdown]
# Para la carga inicial, vamos a crear todas las tablas con una única familia de columnas, `rawdata`, donde meteremos toda la información _raw_ comprimida. Después podremos hacer reorganizaciones de los datos para hacer el acceso más eficiente. Es una de las muchas ventajas de no tener un esquema.

# %%
# Create tables
tables = ['posts', 'votes', 'users', 'tags', 'comments']
for t in tables:
    try:
        with hbasecon.connection() as connection:
            connection.create_table(
                t,
                {
                    'rawdata': dict(max_versions=1,compression='GZ')
                })
    except Exception as e:
        print("Database already exists: {0}. {1}".format(t, e))
        pass
with hbasecon.connection() as connection:
    print(connection.tables())
# Out:
# [b'comments', b'posts', b'tags', b'users', b'votes']

# %% [markdown]
# El código de importación es siempre el mismo, ya que se coge la primera fila del CSV que contiene el nombre de las columnas y se utiliza para generar nombres de columnas dentro de la familia de columnas dada como parámetro. La función `csv_to_hbase()` acepta un fichero CSV a abrir, un nombre de tabla y una familia de columnas donde agregar las columnas del fichero CSV. En nuestro caso siempre va a ser `rawdata`.

# %%
import csv

def csv_to_hbase(file, tablename, cf):
    with hbasecon.connection() as connection, open(file) as f:
        table = connection.table(tablename)

        # La llamada csv.reader() crea un iterador sobre un fichero CSV
        reader = csv.reader(f, dialect='excel')
        
        # Se leen las columnas. Sus nombres se usarán para crear las diferentes columnas en la familia
        columns = next(reader)
        columns = [cf + ':' + c for c in columns]
        
        with table.batch(batch_size=500) as b:
            for row in reader:
                # La primera columna se usará como Row Key
                b.put(row[0], dict(zip(columns[1:], row[1:])))

# %%
for t in tables:
    print("Importando tabla {0}...".format(t))
    # %time csv_to_hbase('../'+t.capitalize() + '.csv', t, 'rawdata')
# Out:
# Importando tabla posts...
# CPU times: user 10.8 s, sys: 281 ms, total: 11.1 s
# Wall time: 22 s
# Importando tabla votes...
# CPU times: user 5.34 s, sys: 99.3 ms, total: 5.44 s
# Wall time: 11.4 s
# Importando tabla users...
# CPU times: user 3.81 s, sys: 108 ms, total: 3.91 s
# Wall time: 8.85 s
# Importando tabla tags...
# CPU times: user 28.7 ms, sys: 24 µs, total: 28.7 ms
# Wall time: 60.7 ms
# Importando tabla comments...
# CPU times: user 4.38 s, sys: 72.6 ms, total: 4.45 s
# Wall time: 8.74 s

# %% [markdown]
# ### Construcción de estructuras anidadas
#
# Al igual que pasaba con MongoDB, las bases de datos NoSQL como en este caso HBase permiten almacenar estructuras de datos complejas. En nuestro caso vamos a agregar los comentarios de cada pregunta o respuesta (post) en columnas del mismo. Para ello, creamos una nueva familia de columnas `comments`.
#
# HBase es bueno para añadir columnas sencillas, por ejemplo que contengan un valor. Sin embargo, si queremos añadir objetos complejos, tenemos que jugar con la codificación de la familia de columnas y columna.
#
# Usaremos el shell porque `happybase` no permite alterar tablas ya creadas.
#
# En el `shell` de HBase pondremos lo siguiente:
#
# ```
# disable 'posts'
# alter 'posts', {NAME => 'comments', VERSIONS => 1}
# enable 'posts'
# ```
#
# Cada comentario que añadimos contiene, al menos:
#
# - un id único
# - un texto
# - un autor
# - etc.
#
# ¿Cómo se consigue meterlo en una única familia de columnas?
#
# Hay varias formas. La que usaremos aquí, añadiremos el **id** de cada comentario como parte del nombre de la columna. Por ejemplo, el comentario con Id 2000, generará las columnas:
#
# - `Id_2000` (valor 2000)
# - `UserId_2000`
# - `PostId_2000`
# - `Text_2000`
#
# con sus correspondientes valores. Así, todos los datos relativos al comentario con Id original 2000, estarán almacenados en todas las columnas que terminen en "`_2000`". La base de datos permite implementar filtros que nos permiten buscar esto de forma muy sencilla. Los veremos después.

# %%
with hbasecon.connection() as connection:
    comments = connection.table('comments')
    posts = connection.table('posts')

    with posts.batch(batch_size=500) as bp:
        # Hacer un scan de la tabla
        for key, data in comments.scan():
            comment = {'comments:' +
                       d.decode('utf-8').split(':')[1] + "_" +
                       key.decode('utf-8') : 
                       data[d].decode('utf-8') for d in data.keys()}
            bp.put(data[b'rawdata:PostId'], comment)

# %% [markdown]
# ## EJERCICIO: Mostrar las filas de la tabla `users` (sólo la columna `rawdata:Location`) de usuarios de España (se supondrá que su localización (columna `rawdata:Location`) contiene `España` o `ES`, obviando mayúsculas y minúsculas).

# %% [markdown]
# Para este ejercicio volvemos a aplicar la función `scan` junto con el parámetro `columns`, para indicar que queremos extraer la columna `rawdata:Location`, y además añadimos un filtro sobre esa columna para que nos muestre únicamente las de usuarios de España. Para obviar las minúsculas y las mayúsculas, el filtro aplicado es de tipo `substring`, que nos permite realizar una comparación *case insensitive*. Para que incluya las localizaciones que contienen tanto España como ES, hemos realizado un `OR` que une los dos filtros `substring`.

# %%
with hbasecon.connection() as connection:
    users = connection.table('users')
    for key,data in users.scan(columns=['rawdata:Location'], 
                               filter="SingleColumnValueFilter('rawdata','Location', =, 'substring:españa') OR SingleColumnValueFilter('rawdata','Location', =, 'substring:ES')"):
        print (key,'->',data[b'rawdata:Location'].decode('utf-8'))
# Out:
# b'-1' -> en la granja de servidores
# b'10039' -> Posadas, Misiónes, Argentina
# b'10136' -> Madrid, España
# b'10137' -> Barcelona, Espanya
# b'1022' -> Santo Domingo Este, Santo Domingo, República Dominicana
# b'10276' -> Barcelona, Espanya
# b'10308' -> Buenos Aires, Argentina
# b'10335' -> Mataró, España
# b'10429' -> Valencia, España
# b'10442' -> Buenos Aires, Argentina
# b'10455' -> Ciudad del Este, Paraguay
# b'1048' -> Raleigh, NC, United States
# b'10497' -> Barcelona, España
# b'10510' -> Tultitlán, Estado de Mexico
# b'10531' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'10576' -> Valencia, España
# b'10629' -> Indore, Madhya Pradesh, India
# b'10642' -> Tortuguitas, Buenos Aires, Argentina
# b'10645' -> Budapest, Hungría
# b'10692' -> Sevilla, España
# b'10699' -> Miami, FL, United States
# b'10744' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'10756' -> Buenos Aires, Argentina
# b'10796' -> Zaragoza, España
# b'10801' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'10834' -> San Francisco, CA, United States
# b'10848' -> Madrid, España
# b'10862' -> Santiago de Compostela, España
# b'10895' -> Madrid, España
# b'10915' -> Valencia, España
# b'10949' -> Resistencia, Chaco, Argentina
# b'10985' -> Clearwater, Florida, Estados Unidos
# b'11034' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'11045' -> Archena, Murcia, España
# b'11074' -> Sydney, New South Wales, Australia
# b'11095' -> Junín, Buenos Aires, Argentina
# b'11114' -> Las Rozas, España
# b'11125' -> Palencia, España
# b'11132' -> Lleida, Cataluña, España
# b'11160' -> Barcelona, España
# b'11201' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'11203' -> Lima, Miraflores, Perú
# b'11210' -> Madrid, España
# b'11310' -> Buenos Aires, Argentina
# b'1136' -> Ensenada, Buenos Aires, Argentina
# b'11384' -> Buenos Aires
# b'1188' -> United States
# b'1199' -> Buenos Aires, Argentina
# b'12' -> Gladstone, MO, United States
# b'1218' -> Tabayesco, Lanzarote, Canary Islands
# b'12495' -> Hurlingham, Buenos Aires, Argentina
# b'12585' -> Salamanca, España
# b'12617' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'12623' -> La Plata, Buenos Aires, Argentina
# b'12686' -> Madrid, España
# b'127' -> Buenos Aires, Argentina
# b'12700' -> Madrid, España
# b'12704' -> Buenos Aires, Argentina
# b'12742' -> South Weber, Utah, United States
# b'12743' -> Buenos Aires, Argentina
# b'12760' -> España
# b'12809' -> Madrid, España
# b'12832' -> Fort Worth, TX, United States
# b'12845' -> Galicia, España
# b'12870' -> Valencia, España
# b'13047' -> Toledo, España
# b'13055' -> Buenos Aires Province, Argentina
# b'13060' -> Miami, FL, United States
# b'1311' -> Buenos Aires, Argentina
# b'13124' -> Sevilla, España
# b'13145' -> Barcelona, España
# b'13151' -> Buenos Aires, Argentina
# b'13187' -> Almeria, Almería, España
# b'13196' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'1321' -> New York, NY, United States
# b'13326' -> Madrid, España
# b'13356' -> Granada, España
# b'13358' -> Granada, España
# b'13365' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'13420' -> Viladecans, Barcelona, Catalunya, Espanya
# b'13424' -> Cerceda, Madrid, España
# b'13477' -> Fuerteventura, Las Palmas, España
# b'13506' -> Córdoba, España
# b'13508' -> Madrid, España
# b'13516' -> Barcelona, España
# b'13518' -> España
# b'13551' -> Barcelona, España
# b'13558' -> Villa Lugano, Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'13567' -> Minneapolis, MN, United States
# b'13598' -> Barcelona, España
# b'13599' -> Madrid, España
# b'13661' -> Granada, España
# b'13664' -> Madrid, España
# b'13666' -> Asturias, España
# b'13774' -> Murcia, España
# b'13800' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'13946' -> Valencia, España
# b'14011' -> Sioux City, IA, United States
# b'14045' -> Barcelona, España
# b'14046' -> Castellón, España
# b'14060' -> Buenos Aires , Argentina
# b'14088' -> Valencia, España
# b'14089' -> Guissona, Lérida, España
# b'14097' -> Madrid, España
# b'14101' -> València, España
# b'14109' -> Santa Cruz de Tenerife, España
# b'14130' -> Estado de Mexico, Naucalpan de Juárez, México
# b'14172' -> España
# b'14178' -> Huelva, España
# b'14188' -> Vinaròs, Castellón, España
# b'14248' -> Sevilla, España
# b'14288' -> Madrid, España
# b'14293' -> Palma de Mallorca, España
# b'143' -> Leicester, United Kingdom
# b'14336' -> Madrid, España
# b'14478' -> Kharagpur, West Bengal, India
# b'14536' -> Barcelona, España
# b'14539' -> Barcelona, España
# b'14547' -> Las Condes, Chile
# b'14579' -> Miami Beach, FL, United States
# b'14587' -> Madrid, España
# b'1461' -> Madrid, España
# b'14615' -> Asturias, España
# b'14650' -> Rafael Calzada, Buenos Aires, Argentina
# b'14657' -> 08830 Sant Boi de Llobregat, España
# b'14671' -> 30180 Bullas, España
# b'14690' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'14707' -> Madrid, España
# b'1473' -> Getxo, Vizcaya, España
# b'14778' -> Madrid, España
# b'14781' -> Madrid, España
# b'14800' -> Boston, Massachusetts, Estados Unidos
# b'14807' -> Alzira, Valencia, España
# b'1481' -> La Rioja - ES
# b'14838' -> Murcia, España
# b'14841' -> Davis, CA, United States
# b'14898' -> Barcelona, España
# b'14901' -> Granada, España
# b'14909' -> A Coruña, España
# b'1491' -> United States
# b'14934' -> Buenos Aires, Argentina
# b'14950' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'1496' -> Santiago de Compostela, España
# b'14962' -> Alicante, España
# b'14964' -> Canary Islands, España
# b'14967' -> Buenos Aires, Argentina
# b'14985' -> Madrid, España
# b'15' -> New York, NY, United States
# b'150' -> Buenos Aires, Argentina
# b'15016' -> Michigan, United States
# b'15038' -> Vigo, España
# b'15047' -> Barcelona, España
# b'15048' -> Zaragoza, España
# b'15049' -> Madrid, España
# b'15076' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'15080' -> Buenos Aires, Argentina
# b'15102' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'15104' -> Madrid, España
# b'15207' -> Granada, España
# b'15220' -> Mallorca, Islas Baleares, España
# b'15225' -> Valladolid, España
# b'15245' -> Córdoba, España
# b'15277' -> Merlo, Buenos Aires, Argentina
# b'15289' -> Barcelona, España
# b'15310' -> San Nicolás de Los Arroyos, Buenos Aires, Argentina
# b'15312' -> Madrid, España
# b'15314' -> Bilbao, Vizcaya, España
# b'15331' -> Soto del Real, Madrid, España
# b'15392' -> Valencia, España
# b'15403' -> Cheste, València, España
# b'1544' -> United States
# b'15447' -> Madrid, España
# b'15450' -> Valencia, España
# b'15455' -> Barcelona, España
# b'15457' -> Catalunya, Espanya
# b'15459' -> Tolosa, España
# b'155' -> Menlo Park, California, Estados Unidos
# b'15514' -> España
# b'15525' -> España
# b'1554' -> Buenos Aires, Argentina
# b'15620' -> Barcelona, España
# b'15621' -> A Coruña, España
# b'15706' -> A Coruña, España
# b'15740' -> Buenos Aires, Argentina
# b'15751' -> Buenos Aires - Argentina
# b'15775' -> Alicante, España
# b'15855' -> Spain, España
# b'15867' -> España
# b'15881' -> Sevilla, España
# b'15899' -> United States
# b'15917' -> Madrid, España
# b'15919' -> Valencia, España
# b'15938' -> Elche, España
# b'15964' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'16008' -> Valencia, España
# b'16066' -> Vigo, España
# b'16090' -> Valencia, España
# b'16108' -> Zaragoza, España
# b'16141' -> Madrid, España
# b'16142' -> Cádiz, España
# b'16150' -> Dubai - United Arab Emirates
# b'16174' -> Buenos Aires, Argentina
# b'16175' -> Madrid, España
# b'16179' -> Buenos Aires, Argentina
# b'16182' -> Burgos, España
# b'16187' -> Bilbao, Vizcaya, España
# b'16191' -> Ciudad Real, España
# b'16196' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'16200' -> Fort Lauderdale, Florida, Estados Unidos
# b'16202' -> Madrid, España
# b'16204' -> Ámsterdam, Países Bajos
# b'16207' -> Barcelona, España
# b'16227' -> El Pinar, Ciudad de la Costa, Departamento de Canelones, Uruguay
# b'16232' -> Ávila, España
# b'16249' -> Corrientes, Argentina
# b'16269' -> Xixón, Asturies, Spain
# b'16280' -> Buenos Aires, Argentina
# b'16285' -> Madrid, España
# b'16299' -> Buenos Aires, Argentina
# b'163' -> Buenos Aires, Argentina
# b'16321' -> Valencia, España
# b'16324' -> Murcia, España
# b'16326' -> Las Palmas de Gran Canaria, España
# b'1633' -> Conquistadores, Medellín - Antioquia, Colombia
# b'16330' -> Madrid, España
# b'16343' -> Huesca, Spain
# b'16379' -> Buenos Aires, Argentina
# b'16381' -> Curitiba - Estado de Paraná, Brasil
# b'16392' -> Leioa, Vizcaya, España
# b'16438' -> Santiago de Compostela, España
# b'16450' -> San Francisco, CA, United States
# b'16469' -> Buenos Aires, Argentina
# b'16470' -> Madrid, España
# b'16480' -> Barcelona, España
# b'16485' -> Buenos Aires, Argentina
# b'16499' -> Cáceres, Spain
# b'16511' -> Buenos Aires, Argentina
# b'16524' -> Madrid, España
# b'16541' -> Buenos Aires, Argentina
# b'16544' -> Madrid, España
# b'16559' -> Orem, Utah, Estados Unidos
# b'16571' -> Buenos Aires, Argentina
# b'16578' -> Barcelona, España
# b'16608' -> San Diego, California, Estados Unidos
# b'16626' -> Brooklyn, NY, United States
# b'16639' -> Jerez de la Frontera, Cádiz, España
# b'16641' -> Granollers, Barcelona, España
# b'16655' -> Salamanca, España
# b'16656' -> Madrid, España
# b'16658' -> Buenos Aires, Argentina
# b'16686' -> Resistencia, Argentina
# b'16701' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'16709' -> San Nicolas de Los Arroyos, Buenos Aires, Argentina
# b'16710' -> Ciudad Autónoma de Buenos Aires, Buenos Aires, Argentina
# b'16714' -> Alicante, España
# b'16734' -> Chicago, Illinois, Estados Unidos
# b'16759' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'16867' -> Manizales, Colombia
# b'16869' -> Madrid, España
# b'16878' -> Buenos Aires, Argentina
# b'1689' -> España, Cangas do Morrazo
# b'16914' -> Morón, Buenos Aires, Argentina
# b'16915' -> Sydney, New South Wales, Australia
# b'16938' -> España
# b'16945' -> Tenerife, Santa Cruz de Tenerife, España
# b'16950' -> Alkmaar, Países Bajos
# b'16952' -> Legazpia, Guipúzcoa, España
# b'16954' -> Ourense, España
# b'16958' -> Sevilla, España
# b'16975' -> Terrassa, España
# b'16982' -> Madrid, España
# b'16987' -> Alicante, España
# b'170' -> United States
# b'17005' -> Alcalá de Henares, Madrid
# b'17007' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'17014' -> Malaga, Málaga, España
# b'17021' -> La Plata, Buenos Aires Province, Argentina
# b'17022' -> Madrid, España
# b'17023' -> Barcelone, Espagne
# b'17026' -> Milton Keynes
# b'17031' -> Buenos Aires, Argentina
# b'17035' -> Bahía Blanca, Buenos Aires Province, Argentina
# b'17041' -> Buenos Aires, Argentina
# b'17049' -> Madrid, España
# b'17063' -> Buenos Aires, Argentina
# b'17066' -> Vigo, Pontevedra, España
# b'17073' -> Buenos Aires, Argentina
# b'17082' -> Tarragona, España
# b'17106' -> Buenos Aires, Argentina
# b'17163' -> Sevilla, España
# b'1718' -> Madrid, España
# b'17186' -> Buenos Aires, Argentina
# b'17220' -> Girona, España
# b'17247' -> Barcelona, España
# b'17256' -> Buenos Aires, Argentina
# b'17272' -> Culiacán Rosales, México
# b'1729' -> Posadas Misiones
# b'17292' -> Madrid, España
# b'1731' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'17342' -> Tandil, Buenos Aires, Argentina
# b'17352' -> Buenos Aires, Argentina
# b'17356' -> Mar del Plata, Buenos Aires, Argentina
# b'17363' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'17368' -> Madrid, España
# b'17425' -> Buenos Aires, Argentina
# b'17467' -> Madrid, España
# b'17481' -> Buenos Aires
# b'17485' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'17510' -> Buenos Aires, Argentina
# b'17518' -> Juan María Gutiérrez, Buenos Aires, Argentina
# b'17532' -> Barcelona, España
# b'17546' -> Buenos Aires, Argentina
# b'17580' -> Donostia, San Sebastián, España
# b'17619' -> Miami, FL, United States
# b'17653' -> Asturias, España
# b'17665' -> Buenos Aires
# b'17672' -> Tandil, Buenos Aires, Argentina
# b'17689' -> Lincoln, Nebraska, Estados Unidos
# b'1769' -> Delray Beach, Florida, Estados Unidos
# b'17702' -> Buenos Aires, Argentina
# b'17719' -> Buenos Aires, Argentina
# b'17753' -> Corrientes, Argentina
# b'17755' -> Sant Fruitós de Bages, Catalonia
# b'17775' -> Pamplona, España
# b'17795' -> España
# b'17810' -> Valladolid, España
# b'17818' -> Vitoria-Gasteiz, Álava, España
# b'17819' -> Sevilla, España
# b'1783' -> Buenos Aires
# b'17833' -> Granollers, España
# b'17846' -> Huelva, España
# b'17849' -> Aviles, Spain
# b'17860' -> Barcelona, España
# b'17864' -> Madrid, España
# b'17867' -> Ciempozuelos, Madrid, España
# b'17873' -> Pamplona, Navarra, España
# b'17875' -> Asturias, España
# b'17879' -> Valencia, España
# b'17883' -> Londres, Reino Unido
# b'17890' -> Esporles, Spain
# b'17941' -> Londres, Reino Unido
# b'17946' -> Sant Cugat del Vallès, Barcelona, España
# b'17955' -> Barcelona, España
# b'17968' -> Barcelona, España
# b'17973' -> Asturias, España
# b'17978' -> Madrid, España
# b'17993' -> Valencia, España
# b'17994' -> León, España
# b'18' -> New York, United States
# b'18005' -> Alcalá de Henares, España
# b'1801' -> Buenos Aires, Argentina
# b'18033' -> Palma de Mallorca, España
# b'18060' -> Aviles, Spain
# b'18087' -> Madrid, España
# b'18090' -> Madrid, España
# b'18091' -> Barcelona, España
# b'18100' -> Barcelona, España
# b'18111' -> Vitoria-Gasteiz, España
# b'18120' -> Galicia, España
# b'18128' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'18171' -> Castellón de la Plana, España
# b'18173' -> Asturias, España
# b'18191' -> Barcelona, España
# b'18222' -> Barcelona, España
# b'18225' -> Arona, Santa Cruz de Tenerife, España
# b'18233' -> Madrid, España
# b'18251' -> Buenos Aires, Argentina
# b'18252' -> Barcelona, España
# b'18260' -> Buenos Aires, Argentina
# b'18322' -> Madrid, España
# b'18344' -> Barcelona, España
# b'18345' -> Oviedo, España
# b'18387' -> Buenos Aires, Argentina
# b'18388' -> Zaragoza, España
# b'18391' -> Valladolid, España
# b'18392' -> España
# b'18406' -> Valencia, España
# b'18410' -> Barcelona, España
# b'18426' -> Buenos Aires, Argentina
# b'18427' -> Culiacán Rosales, México
# b'18453' -> España
# b'18493' -> Oviedo, Asturias, España
# b'18532' -> Hollywood, FL, United States
# b'18556' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'18562' -> Culiacán Rosales, México
# b'18578' -> Pamplona, España
# b'18602' -> Granada, España
# b'1861' -> United States
# b'18615' -> Madrid, España
# b'18625' -> Barcelona, España
# b'18632' -> Madrid, España
# b'18635' -> Valencia, España
# b'18640' -> Madrid, España
# b'18649' -> Madrid, España
# b'18652' -> Miguel Esteban, Spain
# b'18662' -> Madrid, España
# b'18684' -> Vigo, España
# b'18692' -> Utrecht, Países Bajos
# b'18695' -> Barcelona, España
# b'18712' -> Buenos Aires
# b'18716' -> Buenos Aires
# b'18734' -> Resistencia, Argentina
# b'18735' -> Palma de Mallorca, España
# b'18742' -> Buenos Aires, Argentina
# b'1875' -> Siquirres, Costa Rica
# b'18767' -> Buenos Aires, Argentina
# b'18805' -> Madrid, España
# b'18836' -> Guanare, Portuguesa, Venezuela
# b'18879' -> Buenos Aires, Argentina
# b'18896' -> España
# b'18904' -> Madrid, España
# b'18910' -> Barcelona, España
# b'18951' -> United States
# b'18954' -> Barcelona, España
# b'18972' -> Zaragoza, España
# b'1898' -> Leganes, Spain
# b'18992' -> Madrid, España
# b'19' -> Jersey City, NJ, United States
# b'19046' -> Sevilla, España
# b'19059' -> Santiago de Compostela, España
# b'19062' -> Madrid, España
# b'19086' -> Madrid, España
# b'19115' -> Canning, Buenos Aires, Argentina
# b'19128' -> Barcelona, España
# b'19130' -> Madrid, España
# b'19136' -> Buenos Aires, Argentina
# b'19168' -> Vélez-Málaga, España
# b'192' -> Fort Lauderdale, FL, United States
# b'19221' -> Buenos Aires, Argentina
# b'19222' -> Galiza, España
# b'19224' -> Madrid, España
# b'19231' -> Madrid, España
# b'19245' -> Vitoria-Gasteiz, España
# b'19251' -> Vigo, España
# b'19287' -> Albacete, España
# b'19288' -> Barcelona, España
# b'193' -> Buenos Aires, Argentina
# b'19308' -> Buenos Aires, Argentina
# b'19324' -> Philadelphia, PA, United States
# b'19360' -> Madrid, España
# b'19370' -> Madrid, España
# b'19385' -> Fremont, CA, United States
# b'19433' -> Valencia, España
# b'19454' -> Cádiz, España
# b'19458' -> Buenos Aires, Argentina
# b'19459' -> Barcelona, España
# b'19465' -> Badalona, España
# b'19495' -> Jaén, España
# b'19506' -> Buenos Aires, Argentina
# b'19517' -> Buenos Aires, Argentina
# b'19534' -> Buenos Aires, Argentina
# b'19610' -> Málaga, España
# b'19611' -> Palma de Mallorca, España
# b'19623' -> España
# b'19625' -> Valencia, España
# b'19635' -> Cerdanyola Del Valles, Spain
# b'19663' -> Murcia, España
# b'19671' -> Buenos Aires, Argentina
# b'19673' -> España
# b'19674' -> Santander, España
# b'19683' -> Málaga, España
# b'19692' -> Valencia, España
# b'19711' -> Buenos Aires, Argentina
# b'19746' -> Barcelona, España
# b'19761' -> Canary Islands, España
# b'19762' -> Galicia, España
# b'19810' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'19817' -> Fuenlabrada, Madrid, España
# b'19968' -> Malaga, Málaga, España
# b'19971' -> Ciudad Autónoma de Buenos Aires, Buenos Aires, Argentina
# b'19974' -> Madrid, España
# b'1998' -> Cleveland, OH, United States
# b'19985' -> Palma de Mallorca, Islas Baleares, España
# b'20001' -> España
# b'20015' -> España
# b'20016' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'20069' -> Nueva Esparta, Venezuela
# b'20077' -> Buenos Aires, Argentina
# b'2008' -> Buenos Aires, Argentina
# b'20099' -> Madrid, España
# b'20104' -> Barcelona, España
# b'20107' -> Barcelona, España
# b'20111' -> Posadas, Misiónes, Argentina
# b'20130' -> Salamanca, España
# b'20247' -> Madrid, España
# b'20252' -> Barcelona, España
# b'20260' -> Madrid, España
# b'20265' -> Barcelona, España
# b'20270' -> España
# b'20274' -> Cartagena, España
# b'20283' -> A Coruña, La Coruña, España
# b'20285' -> Madrid, España
# b'20307' -> Buenos Aires, Argentina
# b'20326' -> Buenos Aires, Argentina
# b'20350' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'20353' -> Frederico Westphalen - RS, Brasil
# b'20372' -> Valencia, España
# b'20376' -> Valencia, España
# b'20384' -> Barcelona, España
# b'20387' -> Caceres, Spain
# b'20396' -> Buenos Aires, Argentina
# b'20405' -> Madrid, España
# b'20411' -> España
# b'20446' -> Vigo, España
# b'20450' -> Pilar, Buenos Aires, Argentina
# b'20515' -> Santiago de Compostela, España
# b'20564' -> Barcelona, España
# b'2057' -> Chittagong, Bangladesh
# b'2065' -> Buenos Aires
# b'2066' -> Pensacola, FL, United States
# b'2069' -> Los Angeles, CA
# b'20695' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'208' -> New York, United States
# b'20854' -> Death Valley, Condado de Inyo, California, Estados Unidos
# b'20872' -> Barcelona, España
# b'210' -> Austin, TX, United States
# b'21061' -> San Martín de Porres, Lima, Departamento de Lima, Perú
# b'21232' -> Buenos Aires, Argentina
# b'21246' -> Buenos Aires, Argentina
# b'21333' -> Madrid, España
# b'21338' -> Málaga, España
# b'21343' -> Madrid, España
# b'21347' -> Barcelona, España
# b'21350' -> Madrid, España
# b'21359' -> Madrid, España
# b'21367' -> Argentina,Buenos Aires,Hurlingham
# b'21369' -> Moreno, Buenos Aires, Argentina
# b'21517' -> Madrid, España
# b'2153' -> United States
# b'21543' -> Palma, Islas Baleares, Spain
# b'2155' -> Barcelona, España
# b'216' -> Colorado, United States
# b'21628' -> Ciudadela, Buenos Aires, Argentina
# b'21638' -> Málaga, España
# b'21687' -> Donostia, San Sebastián, España
# b'21733' -> Málaga, España
# b'2176' -> New York, NY, United States
# b'21791' -> Valencia, España
# b'21798' -> Dresde, Alemania
# b'21801' -> Alcañiz, Teruel, España
# b'21805' -> Madrid, España
# b'21807' -> Madrid, España
# b'21815' -> Buenos Aires, Argentina
# b'21836' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'21916' -> United States
# b'21923' -> Huelva, España
# b'21931' -> Madrid, España
# b'21945' -> Madrid, España
# b'21976' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'21986' -> Zaragoza, España
# b'21993' -> Alcoy, España
# b'22013' -> Buenos Aires, Argentina
# b'22020' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'22082' -> Madrid, España
# b'22169' -> Madrid, España
# b'22178' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'22195' -> Buenos Aires, Argentina
# b'222' -> Buenos Aires, Argentina
# b'22201' -> La Plata, Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'22224' -> Barcelona, España
# b'22231' -> Madrid, España
# b'22308' -> Málaga, España
# b'22378' -> Madrid y Vitoria-Gasteiz, ES
# b'22410' -> Buenos Aires, Argentina
# b'22433' -> Valencia, España
# b'22435' -> Buenos Aires, Argentina
# b'22441' -> La Plata, Buenos Aires, Argentina
# b'22445' -> Madrid, España
# b'22488' -> Buenos Aires, Argentina
# b'22497' -> Palma de Mallorca, España
# b'22521' -> New York, NY, United States
# b'22550' -> Oviedo, España
# b'22566' -> Buenos Aires, Argentina
# b'22584' -> Santander, España
# b'22590' -> Gavà, Barcelona, España
# b'22595' -> Aguascalientes, Mexico
# b'2264' -> A Coruña, España
# b'22651' -> Barcelona, España
# b'22654' -> Vigo España
# b'22664' -> Madrid, España
# b'22679' -> California, Estados Unidos
# b'22746' -> Tandil, Buenos Aires, Argentina
# b'22754' -> Girona, España
# b'22763' -> Buenos Aires, Argentina
# b'22766' -> Córdoba, España
# b'22769' -> Buenos Aires, Argentina
# b'22771' -> Barcelona, España
# b'22834' -> Estados Unidos
# b'22851' -> Málaga, España
# b'22919' -> Buenos Aires
# b'22936' -> Toledo, España
# b'22952' -> Barcelona, España
# b'23002' -> Barakaldo, Vizcaya, España
# b'23063' -> Valencia, España
# b'2308' -> Madrid, España
# b'2309' -> Buenos Aires, Argentina
# b'23096' -> Zaragoza, España
# b'23105' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'23125' -> Buenos Aires
# b'23156' -> San Sebastián, España
# b'23173' -> Barcelona, España
# b'23174' -> Sabadell, España
# b'23205' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'23234' -> Cádiz, España
# b'23263' -> Mos, Pontevedra, España
# b'23297' -> Santa Cruz de Tenerife, España
# b'2332' -> Buenos Aires, Argentina
# b'23345' -> Barcelona, España
# b'23359' -> Madrid, España
# b'23371' -> Málaga, España
# b'23374' -> Barcelona, España
# b'23396' -> Galicia, España
# b'23401' -> Vigo, España
# b'23407' -> San Antonio, TX, United States
# b'23408' -> Madrid, España
# b'23412' -> Madrid, España
# b'23472' -> Barcelona, España
# b'23475' -> Buenos Aires, Argentina
# b'23491' -> Valencia, España
# b'23508' -> Madrid, España
# b'23560' -> Zaragoza, España
# b'23565' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'23596' -> Sant Cugat del Vallès, España
# b'23597' -> España
# b'23653' -> Granada, España
# b'23655' -> Madrid, España
# b'23657' -> Madrid, España
# b'23663' -> Seville, España
# b'23676' -> Castilla y León, España
# b'23698' -> Manizales - Caldas, Colombia
# b'237' -> West Palm Beach, FL
# b'23714' -> Buenos Aires, Argentina
# b'23731' -> Madrid, España
# b'23777' -> Canarias, España
# b'23778' -> Valencia, España
# b'238' -> Brasil/España
# b'23807' -> Barcelona, España
# b'23824' -> Toluca, Estado de México
# b'23826' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'23878' -> Alicante, España
# b'23879' -> Madrid, España
# b'23881' -> Barcelona, España
# b'23897' -> Buenos Aires, Argentina
# b'23945' -> Madrid, España
# b'23953' -> Madrid, España
# b'23979' -> Madrid, España
# b'23981' -> Madrid, España
# b'23992' -> Madrid, España
# b'24037' -> Barcelona, España
# b'24103' -> Barcelona, España
# b'24128' -> Barcelona, España
# b'24138' -> Madrid, España
# b'24200' -> Valencia, España
# b'24287' -> 406 Foothill Road, Beverly Hills, California, United States
# b'243' -> Vizcaya, España
# b'24314' -> Madrid, España
# b'24317' -> Asturias, España
# b'24321' -> Córdoba, España
# b'24351' -> Uruapan del Progreso, Uruapan, México
# b'24358' -> Córdoba, España
# b'24363' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'24383' -> Buenos Aires, Argentina
# b'24386' -> Barcelona, España
# b'24396' -> Buenos Aires, Argentina
# b'24451' -> Madrid, España
# b'245' -> Buenos Aires, Argentina
# b'24506' -> Buenos Aires, Argentina
# b'24568' -> Buenos Aires, Argentina. Capital Federal.
# b'24599' -> Viladecans, Barcelona, España
# b'24605' -> Madrid, España
# b'24622' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'24656' -> Madrid, España
# b'24673' -> Buenos Aires, Argentina
# b'24675' -> Bilbao, Vizcaya, España
# b'24679' -> Madrid, España
# b'247' -> New York, NY, United States
# b'24760' -> Buenos Aires
# b'24778' -> Madrid, España
# b'24782' -> Barcelona, España
# b'24808' -> Salt Lake City, UT, United States
# b'24818' -> Buenos Aires
# b'24880' -> Culiacán Rosales, México
# b'24895' -> España
# b'249' -> Buenos Aires, Argentina
# b'24909' -> Orlando, Florida, Estados Unidos
# b'24967' -> Barcelona, España
# b'25058' -> Buenos Aires, Argentina
# b'25214' -> España
# b'25306' -> Buenos Aires, Argentina
# b'25327' -> Idaho, United States
# b'25341' -> Madrid, España
# b'25350' -> Autonomous City of Buenos Aires, Argentina
# b'25352' -> General Rodriguez, Buenos Aires, Argentina
# b'25385' -> Buenos aires
# b'25418' -> Barcelona, España
# b'25438' -> Zaragoza, España
# b'25462' -> Juigalpa, Chontales, Nicaragua
# b'25527' -> Buenos Aires
# b'25562' -> Madrid, España
# b'25588' -> Manizales, Caldas, Colombia
# b'25597' -> Villarreal, Castellón, España
# b'25600' -> Getafe, España
# b'25607' -> Valencia, España
# b'25610' -> Palma de Mallorca, España
# b'25620' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'25643' -> Buenos Aires, Argentina
# b'25665' -> Sevilla, España
# b'25679' -> Barcelona, España
# b'25692' -> Miraflores, Arequipa, Perú
# b'25701' -> Lesbos, Prefectura de Lesbos, Grecia
# b'25704' -> Bilbao, España
# b'25713' -> Barcelona, España
# b'25717' -> España
# b'25728' -> Madrid, España
# b'25800' -> España
# b'25897' -> Sevilla, España
# b'25905' -> Kolkata, West Bengal, India
# b'25948' -> Trujillo, Cáceres
# b'25950' -> San Sebastián, España
# b'25971' -> United States
# b'25976' -> Bahía Blanca, Buenos Aires, Argentina
# b'25982' -> Posadas, Misiónes, Argentina
# b'26024' -> Castelldefels, España
# b'26041' -> Getafe, España
# b'26049' -> Vigo, España
# b'26053' -> Madrid, España
# b'26059' -> Albacete, España
# b'26060' -> Resistencia, Chaco, Argentina
# b'26081' -> Madrid, España
# b'26097' -> Madrid, España
# b'26102' -> Madrid, España
# b'26106' -> Utah, United States
# b'26132' -> Barcelona, España
# b'26137' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'26164' -> Madrid, España
# b'26165' -> Madrid, España
# b'26167' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'26175' -> Valencia, España
# b'26180' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'26195' -> España
# b'26218' -> Barcelona, España
# b'26220' -> Buenos Aires, Argentina
# b'26226' -> Estado de México, México
# b'26239' -> Barcelona, España
# b'26240' -> Zaragoza, España
# b'26241' -> Barcelona, España
# b'26263' -> Pola de Lena, España
# b'26264' -> 76903 Candiles, México
# b'26290' -> Padrón, España
# b'26323' -> Barcelona, España
# b'26324' -> Toledo, España
# b'26336' -> Cocoa Avenue, Hershey, Pensilvania, Estados Unidos
# b'2634' -> United States
# b'26347' -> España
# b'26354' -> El Puig, Valencia, España
# b'26389' -> España, Madrid
# b'26414' -> Vigo, España
# b'26417' -> Mar del Plata, Buenos Aires, Argentina
# b'26423' -> Madrid, España
# b'26465' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'26472' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'26489' -> Avila, España
# b'265' -> Buenos Aires, Argentina
# b'26547' -> Madrid, España
# b'26548' -> Madrid, España
# b'26554' -> Barcelona, España
# b'26555' -> Seattle, WA, United States
# b'26556' -> Madrid, España
# b'26574' -> España
# b'26625' -> Barcelona, España
# b'26650' -> Madrid, España
# b'26656' -> Bilbao, Vizcaya, España
# b'26696' -> Florida, United States
# b'26703' -> Banyeres de Mariola (Alicante)
# b'26735' -> Madrid, España
# b'2676' -> España
# b'268' -> United States
# b'26808' -> Oregon, United States
# b'26837' -> Ciudad Jardin Lomas de Palomar, Buenos Aires, Argentina
# b'26841' -> Santiago de Compostela, España
# b'26842' -> Valencia, España
# b'26844' -> Huesca, España
# b'26848' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'26914' -> New York, United States
# b'26926' -> Puerto de Sagunto, España
# b'26929' -> Barcelona, España
# b'26954' -> Palma de Mallorca, España
# b'27021' -> España
# b'27029' -> Manizales, Caldas, Colombia
# b'27129' -> Los Angeles, CA
# b'27133' -> Ciudad de Buenos Aires, Argentina
# b'27154' -> Valencia, España
# b'27167' -> Huelva, España
# b'27198' -> Buenos Aires, Argentina
# b'2720' -> Murcia, España
# b'27216' -> United States
# b'27218' -> Buenos Aires, Argentina
# b'27230' -> Madrid, España
# b'27239' -> Madrid, España
# b'27243' -> Madrid, España
# b'27244' -> Buenos Aires, Argentina
# b'27264' -> Buenos Aires
# b'27270' -> Buenos Aires, Argentina
# b'27297' -> España
# b'27326' -> Manizales, Caldas, Colombia
# b'27327' -> Buenos Aires, Argentina
# b'27367' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'27368' -> Bilbao, Vizcaya, España
# b'27392' -> Argentina, BUenos aires
# b'27398' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'2741' -> United States
# b'27427' -> Mar del Plata, Buenos Aires, Argentina
# b'27445' -> Manresa, España
# b'27459' -> Menorca, Illes Balears, Espanya
# b'2748' -> España
# b'27515' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'27527' -> Aguascalientes, México
# b'27530' -> Buenos Aires, Argentina
# b'27556' -> California, Estados Unidos
# b'27577' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'27601' -> Elche, España
# b'27606' -> Madrid, España
# b'27612' -> Adra, España
# b'27650' -> Richmond, VA, United States
# b'27653' -> Buenos Aires, Argentina
# b'27667' -> España
# b'27679' -> Barcelona, España
# b'27711' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'27721' -> Salt Lake City, UT, United States
# b'27763' -> Santa Monica, CA, United States
# b'27792' -> Capital Federal, Buenos Aires, Argentina
# b'27816' -> Buenos Aires
# b'27826' -> Bilbao, España
# b'27833' -> Manizales - Caldas, Colombia
# b'27847' -> Santander, España
# b'27912' -> Valencia, España
# b'27916' -> Santander, España
# b'27920' -> Madrid, España
# b'27990' -> Progreso, Yucatán
# b'28068' -> Manizales, Caldas, Colombia
# b'28076' -> Portland, OR, United States
# b'2809' -> Hyde Park, Nueva York, Estados Unidos
# b'28094' -> Sevilla, España
# b'2811' -> Fort Collins, CO, United States
# b'28110' -> Barcelona, España
# b'28132' -> Buenos Aries, Argentina
# b'2817' -> Caceres, Spain
# b'28176' -> Sevilla, España
# b'28181' -> Barcelona, España
# b'28190' -> España
# b'28206' -> La Plata, Buenos Aires, Argentina
# b'28221' -> Buenos Aires, Argentina
# b'28270' -> Barcelona, España
# b'28284' -> Burgos, España
# b'28320' -> Madrid, España
# b'28336' -> Madrid, España
# b'28360' -> Alicante, España
# b'28366' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'28368' -> Ceuta, España
# b'28373' -> Laredo, Texas, Estados Unidos
# b'28382' -> Las Rozas de Madrid, Madrid, España
# b'28419' -> Buenos Aires, Argentina
# b'28423' -> Barcelona, España
# b'28440' -> Miami, Florida, Estados Unidos
# b'28458' -> Madrid, España
# b'2847' -> Granada, España
# b'28472' -> Buenos Aires, Argentina
# b'28483' -> Madrid, España
# b'28496' -> Quilmes, Argentina
# b'28537' -> Barcelona, España
# b'28543' -> Igualada, Barcelona, Espanya
# b'28548' -> Madrid, Espagne
# b'28603' -> Buenos Aires, Argentina
# b'28616' -> Barcelona, España
# b'28618' -> Madrid, España
# b'28622' -> Valencia, España
# b'28624' -> Mallorca, Islas Baleares, España
# b'28629' -> Barcelona, España
# b'28661' -> Los Angeles, CA
# b'28668' -> Buenos Aires, Argentina
# b'28728' -> Granada, España
# b'28732' -> Huelva, España
# b'28734' -> Madrid, España
# b'28739' -> Valencia, España
# b'28761' -> Málaga, España
# b'28771' -> Barcelona, España
# b'28791' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'28806' -> Zamora, España
# b'28829' -> Argentina, Ramos Mejía, Buenos Aires
# b'2886' -> Forest of Dean, United Kingdom
# b'28861' -> Madrid, España
# b'28868' -> Barcelona, España
# b'28870' -> Madrid, España
# b'28903' -> Madrid, España
# b'28912' -> Tarragona, Espanya
# b'28932' -> Houston, Texas, Estados Unidos
# b'28933' -> Buenos Aires, Argentina
# b'28971' -> Madrid, España
# b'28976' -> Barcelona, España
# b'28977' -> Alicante, España
# b'28999' -> Fullerton, CA, United States
# b'29011' -> Les Franqueses del Valles
# b'29032' -> Spain Street, Nueva Orleans, Luisiana, Estados Unidos
# b'29072' -> Madrid, España
# b'29081' -> Palma de Mallorca, España
# b'29084' -> Barcelona, España
# b'29155' -> Barcelona, España
# b'29223' -> Malaga, Málaga, España
# b'29257' -> España
# b'29261' -> Buenos Aires
# b'29295' -> Barcelona, España
# b'29315' -> Murcia, España
# b'29420' -> Buenos Aires, Argentina
# b'29437' -> Posadas, Misiónes, Argentina
# b'29443' -> Boston, MA, United States
# b'29448' -> La Coruña, España
# b'29451' -> Madrid, España
# b'29457' -> La Plata, Buenos Aires Province, Argentina
# b'29463' -> Vitoria-Gasteiz, España
# b'29467' -> Santa Cruz de Tenerife, España
# b'29485' -> España
# b'29492' -> Buenos Aires, Argentina
# b'29493' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'29511' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'29532' -> Madrid, España
# b'29533' -> Basque Country, España
# b'2954' -> Sevilla, España
# b'29572' -> Vigo, Pontevedra, España
# b'2958' -> Buenos Aires - Argentina
# b'29620' -> Islas Canarias, España
# b'2966' -> Miami, FL, United States
# b'29738' -> Morón, Buenos Aires, Argentina
# b'29772' -> Davao City, Davao Region, Philippines
# b'29784' -> España
# b'29786' -> Valencia, España
# b'29790' -> Zaragoza, España
# b'29793' -> Llíria, Liria, España
# b'29832' -> Madrid, España
# b'29872' -> Madrid, España
# b'29936' -> Las Palmas de Gran Canaria, España
# b'29955' -> Lugo, España
# b'29956' -> Mahón, Islas Baleares, España
# b'29957' -> Madrid, España
# b'29963' -> Zaragoza, España
# b'29976' -> A Coruña, España
# b'29979' -> Santiago de Compostela, España
# b'2999' -> United States
# b'30024' -> Buenos Aires, Argentina
# b'3004' -> En las nubes
# b'30085' -> León, España
# b'30097' -> Zumaia, Guipúzcoa, España
# b'30110' -> Málaga, España
# b'30116' -> Sevilla, España
# b'30124' -> Buenos Aires, Argentina
# b'30136' -> Resistencia, Argentina
# b'30174' -> Écija, Sevilla, España
# b'30176' -> Extremadura, España
# b'30206' -> Santa Coloma de Gramanet, España
# b'30215' -> Palma de Mallorca, España
# b'30245' -> A Coruña, La Coruña, España
# b'30255' -> Barcelona, España
# b'30257' -> Santander, Cantabria, España
# b'30277' -> Sant Feliu de Guíxols, España
# b'30287' -> Bilbao, España
# b'3029' -> Manchester, United Kingdom
# b'30292' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'303' -> Monmouth, NJ, United States
# b'30354' -> Esquel, Chubut, Argentina
# b'30364' -> Zaragoza, España
# b'30366' -> Madrid, España
# b'30367' -> Madrid, España
# b'30373' -> Murcia, España
# b'30381' -> Madrid, España
# b'30395' -> Santa Cruz de Tenerife, España
# b'30401' -> Madrid, España
# b'30417' -> Posadas Misiones
# b'30421' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'30439' -> Barcelona, Espanya
# b'3046' -> La Mesa, CA
# b'30461' -> Charles Town, WV
# b'30522' -> Miami, FL, United States
# b'30525' -> San Fernando, Cádiz, España
# b'30527' -> España
# b'30541' -> Buenos Aires, Argentina
# b'30543' -> Estado de México, Mexico
# b'30551' -> León, España
# b'30569' -> Valencia, España
# b'30571' -> Culiacán Rosales, México
# b'30576' -> Londres, Reino Unido
# b'30604' -> Murcia, España
# b'30620' -> Barcelona, España
# b'30628' -> Buenos Aires, Argentina
# b'30635' -> Buenos Aires, Argentina
# b'30705' -> Odenton, MD, United States
# b'30727' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'30737' -> Barcelona, España
# b'30740' -> Tallinn, Estonia
# b'3078' -> Galicia, España
# b'30801' -> Barcelona, España
# b'30812' -> Madrid, España
# b'30831' -> Madrid, España
# b'30834' -> Cáceres, España
# b'30838' -> Buenos Aires, Argentina
# b'3084' -> Barcelona, Catalunya, Espanya
# b'30879' -> Buenos Aires, Argentina
# b'30935' -> Londres, Reino Unido
# b'30967' -> Sant Cugat del Vallès, España
# b'30977' -> Madrid, España
# b'30988' -> Barcelona, España
# b'30992' -> Buenos Aires, Argentina
# b'31065' -> España
# b'31067' -> Barcelona, España
# b'31072' -> Barcelona, España
# b'3111' -> Buenos Aires, Argentina
# b'31117' -> Austin, TX, United States
# b'31163' -> La Rioja, España
# b'31218' -> Madrid, España
# b'3122' -> Madrid, España
# b'31271' -> España
# b'3135' -> Estocolmo, Suecia
# b'31384' -> Madrid, España
# b'31401' -> Buenos Aires, AR
# b'31405' -> Madrid, España
# b'31429' -> Mar del Plata, Buenos Aires Province, Argentina
# b'31483' -> Vigo, Pontevedra, España
# b'3149' -> Buenos Aires, Argentina
# b'31494' -> Málaga, España
# b'31514' -> Barcelona, España
# b'31546' -> Buenos Aires, Argentina
# b'31549' -> Málaga, España
# b'31554' -> Buenos Aires
# b'31570' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'31596' -> Seville, España
# b'31599' -> Madrid, España
# b'31616' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'31617' -> Buenos Aires, Argentina
# b'31620' -> Barcelona, España
# b'31628' -> Sevilla, España
# b'31682' -> Corrientes, Argentina
# b'31734' -> Madrid, España
# b'31858' -> Murcia, España
# b'31866' -> Granada, España
# b'31871' -> Barcelona, España
# b'31872' -> Alicante, España
# b'31886' -> Corrientes, Argentina
# b'31905' -> Madrid, España
# b'31913' -> Rincón de la Victoria, España
# b'31930' -> Badajoz, España
# b'31932' -> España
# b'31977' -> Barcelona, España
# b'31995' -> Buenos Aires, Argentina
# b'32032' -> Alicante, España
# b'32065' -> Buenos Aires Province, Argentina
# b'32070' -> España
# b'32071' -> España
# b'32073' -> Madrid, España
# b'32077' -> Durango, España
# b'32084' -> Madrid, España
# b'32095' -> Orihuela, Alicante, España
# b'32190' -> Madrid, España
# b'32193' -> Granada, España
# b'32194' -> Zaragoza, España
# b'32224' -> Granada, España
# b'32228' -> Anaheim, CA, United States
# b'32248' -> Bilbao, Vizcaya, España
# b'3227' -> Seville, España
# b'32285' -> Valencia, España
# b'32289' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'32341' -> Barcelona, España
# b'32384' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'32422' -> España
# b'32435' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'32475' -> Buenos Aires, Autonomous City of Buenos Aires Argentina
# b'32512' -> San Cristóbal de La Laguna, Santa Cruz de Tenerife, España
# b'32526' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'32571' -> Madrid, España
# b'32573' -> Barcelona, España
# b'32606' -> Madrid, España
# b'32635' -> Barcelona, España
# b'32641' -> Buenos Aires, Argentina
# b'32647' -> Cáceres, España
# b'32653' -> Buenos Aires
# b'3266' -> Buenos Aires, Argentina
# b'32674' -> Santo Domingo Este, Santo Domingo Province, Dominican Republic
# b'32679' -> Burjassot, Valencia, España
# b'32716' -> Buenos Aires, Argentina
# b'32726' -> Canary Islands, España
# b'32751' -> Jackson, TN, United States
# b'32767' -> Valencia, España
# b'32856' -> Buenos Aires
# b'32892' -> Alcoy, Alicante, España
# b'32893' -> Madrid, España
# b'32895' -> Barcelona, España
# b'32897' -> Madrid, España
# b'32905' -> Madrid, España
# b'32907' -> Madrid, España
# b'32912' -> Barcelona, España
# b'32915' -> Buenos Aires, Argentina
# b'32930' -> Asturias, España
# b'32947' -> Madrid, España
# b'32964' -> Santander, España
# b'32965' -> Vitoria-Gasteiz, España
# b'32969' -> España
# b'32988' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'33016' -> Barcelona, España
# b'3302' -> Manresa, Spain
# b'33066' -> Madrid, España
# b'33072' -> Langreo, Asturias, España
# b'33095' -> Buenos Aires, Argentina
# b'33098' -> Benidorm, España
# b'33174' -> Huejutla de Reyes, México
# b'33193' -> Madrid, España
# b'33203' -> Málaga, España
# b'33259' -> España
# b'33260' -> Buenos Aires
# b'33264' -> Barcelona, España
# b'33271' -> Madrid, España
# b'33305' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'33345' -> Cartagena, Murcia, España
# b'33380' -> Rubí, España
# b'33401' -> Madrid, España
# b'33443' -> Murcia, España
# b'33478' -> Cuenca, España
# b'3353' -> Madrid, España
# b'33623' -> Barcelona, España
# b'33632' -> Zaragoza, España
# b'33638' -> Granada, España
# b'33650' -> Malaga, Málaga, España
# b'33675' -> Alcoy, Alicante, España
# b'33722' -> Elche, Alicante, España
# b'33788' -> New York, NY, United States
# b'33808' -> Barcelona, España
# b'33823' -> Madrid, España
# b'33921' -> Madrid, España
# b'33927' -> Elche, Alicante, España
# b'33929' -> Pamplona, España
# b'33930' -> Córdoba, España
# b'33951' -> Sevilla, España
# b'33959' -> Lugones, España
# b'33962' -> Barcelona, España
# b'33968' -> Amurrio, Álava, España
# b'34044' -> Valencia, España
# b'34048' -> Alicante, España
# b'3411' -> Granada, España
# b'3415' -> Buenos aires
# b'34159' -> McKinney, Texas, Estados Unidos
# b'34174' -> Santa Cruz de Tenerife, España
# b'34181' -> España
# b'3419' -> Manizales, Caldas, Colombia
# b'34259' -> Huesca, España
# b'34274' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'34318' -> Wales, United Kingdom
# b'34324' -> España
# b'34331' -> Colón, Buenos Aires, Argentina
# b'34375' -> Buenos Aires, Argentina
# b'34404' -> Madrid, España
# b'34405' -> Valladolid, España
# b'34433' -> Buenos Aires, Argentina
# b'34442' -> Barcelona, España
# b'34472' -> Buenos Aires
# b'34507' -> CABA, Ciudad Autónoma de Buenos Aires, Argentina
# b'34603' -> Buenos Aires, Argentina
# b'34667' -> Fort Worth, TX, United States
# b'34673' -> Estado de México
# b'3468' -> Canarias, España
# b'34690' -> Canarias, España
# b'34743' -> Miami, Florida, Estados Unidos
# b'34805' -> Amorebieta-Etxano, Vizcaya, España
# b'34829' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'34831' -> Derio, Vizcaya, España
# b'34841' -> León, España
# b'34843' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'34865' -> Buenos Aires, Argentina
# b'3492' -> Buenos Aires, Argentina
# b'34930' -> Miraflores, Peru
# b'34938' -> Valledupar - Cesar, Colombia
# b'34969' -> Barcelona, España
# b'34994' -> España
# b'35055' -> Madrid, España
# b'35127' -> Barcelona, España
# b'35201' -> Johannesburg, Gauteng, South Africa
# b'35203' -> Barcelona, España
# b'35264' -> España
# b'35269' -> Buenos Aires, Argentina
# b'3538' -> Palma de Mallorca, España
# b'35415' -> Barcelona, España
# b'35436' -> Bilbao, España
# b'35437' -> Madrid, España
# b'35439' -> Madrid, España
# b'35455' -> Madrid, España
# b'35471' -> Colorado, Estados Unidos
# b'3553' -> Madrid, España
# b'35560' -> Argentina, Ramos Mejía, Buenos Aires
# b'3559' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'356' -> Buenos Aires
# b'35636' -> España
# b'35638' -> Andalucía, España
# b'35659' -> Senda de Granada, 31 Apdo. nº 67 30100 - Espinardo (Murcia)
# b'35669' -> California, United States
# b'35670' -> Barcelona, España
# b'35679' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'35685' -> Valencia, España
# b'3569' -> Bilbao, España
# b'35727' -> Madrid, España
# b'35764' -> United States
# b'35827' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'35833' -> Irún, Guipúzcoa, España
# b'35866' -> José C. Paz, Buenos Aires, Argentina
# b'35877' -> Madrid, España
# b'35879' -> Granada, España
# b'35956' -> Madrid, España
# b'3598' -> Málaga, España
# b'3600' -> Albacete, España
# b'36029' -> Murcia, España
# b'3603' -> Valencia, España
# b'36041' -> Sevilla, España
# b'3610' -> Madrid, España
# b'36169' -> Barcelona, Espanya
# b'36170' -> Madrid, España
# b'36178' -> España
# b'3644' -> Granada, España
# b'3654' -> Madrid, España
# b'368' -> Pasadena, MD 21122, United States
# b'3687' -> Virginia, United States
# b'3695' -> Madrid, España
# b'3719' -> Algeciras, España
# b'3720' -> Tarragona, España
# b'37248' -> Andújar, Jaén, España
# b'37283' -> Madrid, España
# b'3729' -> España
# b'37296' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'37387' -> Barcelona, España
# b'37436' -> León, España
# b'37488' -> Alicante, España
# b'3751' -> Madrid, España
# b'37541' -> España
# b'37548' -> Madrid, España
# b'37566' -> Murcia, España
# b'3758' -> Galicia, España
# b'37593' -> Barcelona, España
# b'37610' -> Madrid, España
# b'3762' -> Mataró, España
# b'37626' -> Idaho Falls, ID, United States
# b'37631' -> Valledupar - Cesar, Colombia
# b'37673' -> Baleares
# b'37677' -> Barcelona, España
# b'37712' -> España
# b'37750' -> Valencia, España
# b'37763' -> Madrid, España
# b'3781' -> Madrid, España
# b'37810' -> Gerona, España
# b'37820' -> Madrid, España
# b'37886' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'37933' -> Rochester, NY, United States
# b'37960' -> Vermont, United States
# b'37968' -> Mar del Plata, Buenos Aires, Argentina
# b'38018' -> Madrid, España
# b'38024' -> Santander, España
# b'38044' -> Miami, FL, United States
# b'38065' -> Sevilla, España
# b'38136' -> Buenos Aires, Argentina
# b'38213' -> Las Palmas de Gran Canaria, España
# b'38222' -> Granada, España
# b'38252' -> Resistencia, Chaco Province, Argentina
# b'38277' -> Ciudad del Este, Paraguay
# b'38300' -> Madrid, España
# b'38369' -> Sevilla, España
# b'38379' -> Madrid, España
# b'38388' -> Alicante, España
# b'38391' -> Buenos Aires, Argentina
# b'38396' -> CABA, Ciudad Autónoma de Buenos Aires, Argentina
# b'38482' -> Vitoria, Vitoria-Gasteiz, España
# b'38512' -> Junín, Buenos Aires Province, Argentina
# b'38539' -> Madrid, España
# b'38558' -> Murcia, España
# b'38560' -> Madrid, España
# b'3858' -> Lewisville, TX, United States
# b'38600' -> Albacete, España
# b'38622' -> Buenos Aires, Argentina
# b'38636' -> Estado de México, México
# b'38647' -> Aviles, Spain
# b'38668' -> United States
# b'38708' -> Saint-Dié-des-Vosges, Francia
# b'38771' -> Madrid, España
# b'38779' -> Los Andes, Chile
# b'38808' -> Aguascalientes, México
# b'38862' -> Sevilla, España
# b'38901' -> Simat de Valldigna, Valencia, España
# b'38961' -> Buenos Aires, Argentina
# b'3899' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'3900' -> Barcelona, España
# b'39000' -> Málaga, España
# b'39004' -> Barcelona, España
# b'39007' -> Madrid, España
# b'39030' -> Malaga, Málaga, España
# b'39043' -> Zaragoza, España
# b'39109' -> Moreno, Buenos Aires, Argentina
# b'3912' -> Manchester, United Kingdom
# b'3916' -> Houston, TX, United States
# b'39210' -> Madrid, España
# b'39213' -> Miami, FL, United States
# b'39252' -> Aguascalientes, México
# b'39279' -> Valencia, España
# b'39381' -> Barcelona, España
# b'39420' -> Quesada, San Carlos, Alajuela Province, Costa Rica
# b'39428' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'39442' -> Sevilla, España
# b'39465' -> Jacksonville, FL, United States
# b'39478' -> Ciudad Autónoma de Buenos Aires, Buenos Aires, Argentina
# b'39508' -> Barcelona, España
# b'39513' -> Resistencia, Chaco, Argentina
# b'3953' -> Buenos Aires, Argentina
# b'39530' -> Buenos Aires, Argentina
# b'39548' -> Barcelona, España
# b'39618' -> Ourense, España
# b'39623' -> Buenos Aires, Argentina
# b'39667' -> Málaga, España
# b'39690' -> Móstoles, Madrid, España
# b'39708' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'39786' -> A Coruña, España
# b'39795' -> Madrid, España
# b'39811' -> Vigo, España
# b'39892' -> Córdoba, España
# b'39952' -> Valencia, España
# b'39954' -> Madrid, España
# b'39957' -> Madrid, España
# b'39962' -> España
# b'39964' -> Alicante, España
# b'39987' -> Palma de Mallorca, Islas Baleares, España
# b'40012' -> Bilbao, Vizcaya, España
# b'40028' -> Ciudad Autónoma de Buenos Aires, Buenos Aires, Argentina
# b'40080' -> Dubai, United Arab Emirates
# b'40110' -> Cádiz, España
# b'40206' -> Sanlúcar de Barrameda, España
# b'40248' -> Carlet, Valencia, España
# b'40280' -> Buenos Aires, Argentina
# b'4029' -> Bangladesh
# b'40419' -> Barcelona, España
# b'40443' -> Buenos Aires, Argentina
# b'40467' -> Leganés, España
# b'40509' -> Bilbao, Vizcaya, España
# b'40530' -> Las Palmas, España
# b'40625' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'407' -> Málaga, España
# b'4072' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'40740' -> San Martín de Porres, Distrito de Lima, Lima, Peru
# b'40776' -> Alicante, España
# b'40777' -> Bilbao, España
# b'40779' -> Madrid, España
# b'40791' -> Las Palmas de Gran Canaria, España
# b'40830' -> Miami Beach, Florida, Estados Unidos
# b'40833' -> Barcelona, España
# b'40925' -> Barcelona, España
# b'40961' -> Area Metropolitana de Barcelona, Barcelona, España
# b'40999' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'41003' -> Manizales, Colombia
# b'41050' -> Alcalá de Henares, España
# b'41056' -> Santa Cruz de Tenerife, España
# b'41103' -> Tigre, Buenos Aires, Argentina
# b'41106' -> San Francisco, CA, United States
# b'41110' -> San Antonio de Areco, Buenos Aires, Argentina
# b'41233' -> Huesca, España
# b'41350' -> Buenos Aires, Argentina
# b'4136' -> Ciudad del Este, Paraguay
# b'4139' -> España
# b'41510' -> Barcelona, España
# b'41511' -> Malaga, Málaga, España
# b'41574' -> Mataró, España
# b'41581' -> Tandil, Buenos Aires, Argentina
# b'41611' -> Buenos Aires, Argentina
# b'41621' -> Granada, España
# b'41638' -> Madrid, España
# b'41650' -> Madrid, España
# b'41654' -> Barcelona, España
# b'41676' -> Ermua, Vizcaya, España
# b'41707' -> Capital, Corrientes, Argentina
# b'41731' -> España
# b'41753' -> Buenos Aires, Argentina
# ...
# b'48623' -> Estados Unidos
# b'48634' -> Sevilla, España
# b'48717' -> A Coruña, España
# b'48746' -> Madrid, España
# b'48762' -> Buenos Aires, Argentina
# b'48764' -> Moraña, Pontevedra, España
# b'4880' -> Collado Villalba, España
# b'48800' -> Sorocaba - Estado de São Paulo, Brasil
# b'48812' -> Tenerife, Santa Cruz de Tenerife, España
# b'4883' -> Granada, España
# b'48839' -> Buenos Aires
# b'48860' -> Barcelona, España
# b'48864' -> Madrid, España
# b'48868' -> Albacete, España
# b'48882' -> Buenos Aires, Argentina
# b'48947' -> Buenos Aires, Argentina
# b'48959' -> La Plata, Buenos Aires, Argentina
# b'4897' -> Buenos Aires, Argentina
# b'48988' -> Alhama de Murcia, España
# b'48998' -> Barcelona, Espanya
# b'49001' -> Almería, España
# b'49004' -> Buenos Aires, Argentina
# b'49165' -> Barcelona, España
# b'49168' -> La Rioja, España
# b'49169' -> Vitoria-Gasteiz, España
# b'49180' -> Buenos Aires
# b'49181' -> Galicia, España
# b'49313' -> Consuegra, Toledo, España
# b'49326' -> Las Palmas de Gran Canaria, España
# b'49358' -> Valencia, España
# b'49381' -> Santo Domingo Este, Santo Domingo, República Dominicana
# b'49428' -> Buenos Aires, Argentina
# b'49489' -> La Llosa, Castellón, España
# b'49570' -> Madrid, España
# b'49576' -> Madrid, España
# b'49610' -> Buenos Aires, Argentina
# b'49619' -> La Plata, Buenos Aires, Argentina
# b'49701' -> Buenos Aires, Argentina
# b'49705' -> La Parra, España
# b'49770' -> Barcelona, Espanya
# b'49778' -> Burgos, España
# b'4978' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'49833' -> United States
# b'49844' -> Buenos Aires, Argentina
# b'49854' -> Buenos Aires - Argentina
# b'4986' -> Madrid, España
# b'49878' -> Buenos Aires, Argentina
# b'49901' -> Madrid, España
# b'49903' -> Campo de Criptana, Ciudad Real, España
# b'49914' -> Buenos Aires, Argentina
# b'49983' -> Barcelona, España
# b'49990' -> Resistencia, Chaco, Argentina
# b'50057' -> Irún, Guipúzcoa, España
# b'50070' -> Jakarta, Indonesia
# b'50112' -> Tampa, FL, United States
# b'50173' -> Buenos Aires, Argentina
# b'50191' -> Barcelona, España
# b'50192' -> Sevilla, España
# b'50207' -> Málaga, España
# b'50247' -> Ciudad Autónoma de Buenos Aires, Buenos Aires, Argentina
# b'50329' -> Madrid, España
# b'50361' -> Barcelona, España
# b'50392' -> Algeciras, Cádiz, España
# b'50396' -> Lloret de Mar, España
# b'50403' -> Somerville, MA, United States
# b'50438' -> Aguascalientes, Mexico
# b'50493' -> Madrid, España
# b'50509' -> Charlotte, NC, United States
# b'50545' -> Barcelona, España
# b'50622' -> Madrid, España
# b'50638' -> Buenos Aires, Argentina
# b'50717' -> Barcelona, España
# b'50755' -> Madrid, España
# b'50758' -> Vigo, España
# b'508' -> Barcelona, España
# b'50808' -> Vigo, Pontevedra, España
# b'50820' -> Aguascalientes, México
# b'50905' -> Barcelona, España
# b'50923' -> Torrejón de Ardoz, España
# b'50955' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'51005' -> Huelva, España
# b'51012' -> Soria, España
# b'51015' -> Galicia, España
# b'5105' -> Buenos Aires, Argentina
# b'51061' -> Zaragoza, España
# b'51069' -> Barcelona, España
# b'51184' -> Santa Clara, CA, United States
# b'51210' -> A Coruña, España
# b'51232' -> Antequera, Málaga, España
# b'51258' -> Buenos Aires, Argentina
# b'51293' -> Baradero, Buenos Aires, Argentina
# b'51311' -> Valencia, España
# b'51312' -> Madrid, España
# b'51340' -> Madrid, España
# b'51352' -> Barcelona, España
# b'51370' -> Valencia, España
# b'51460' -> San Sebastián, España
# b'51499' -> Buenos Aires, Argentina
# b'51526' -> Santander, Cantabria, España
# b'51553' -> Madrid, España
# b'51636' -> Madrid, España
# b'51639' -> España
# b'51659' -> Barcelona, España
# b'51713' -> Madrid, España
# b'51715' -> Tarragona, España
# b'51716' -> Sevilla, España
# b'51717' -> Granada, España
# b'51731' -> Chicago, IL, United States
# b'518' -> Buenos Aires, Argentina
# b'5180' -> http://www.solucionesrios.tk/
# b'5181' -> San Diego, CA, United States
# b'51825' -> Sevilla, España
# b'51833' -> Barcelona, España
# b'51837' -> Puertollano, España
# b'51900' -> Omnipresent
# b'51966' -> Mallorca, Islas Baleares, España
# b'51967' -> Valladolid, España
# b'51969' -> Las Palmas de Gran Canaria, España
# b'51975' -> Bilbao, España
# b'51994' -> Barcelona, España
# b'52031' -> Dresden
# b'52049' -> Elda, España
# b'52055' -> Mar del Plata, Buenos Aires, Argentina
# b'52062' -> United States
# b'52110' -> Vigo, Pontevedra, España
# b'52115' -> Murcia, España
# b'52122' -> Madrid, España
# b'52140' -> Puertollano, Ciudad Real, España
# b'52143' -> Buenos Aires, Argentina
# b'52163' -> Valencia, España
# b'52195' -> Aguascalientes, México
# b'52257' -> Madrid, España
# b'52291' -> Morón, Buenos Aires, Argentina
# b'52335' -> Bali, Indonesia
# b'52338' -> Barcelona, España
# b'52352' -> Estado Sucre, Venezuela
# b'52367' -> Valencia, España
# b'52463' -> Buenos Aires, Argentina
# b'52470' -> Villa Mercedes, San Luis, Argentina
# b'5264' -> Pittsburgh, PA, United States
# b'5265' -> Jaén, España
# b'5270' -> Culiacán Rosales, México
# b'5305' -> Barcelona, España
# b'5307' -> Segovia, España
# b'5321' -> Buenos Aires, Argentina
# b'53506' -> Canary Islands, España
# b'53509' -> España
# b'53513' -> Las Palmas de Gran Canaria, España
# b'53515' -> United States
# b'53580' -> Málaga, España
# b'53617' -> Buenos Aires, Argentina
# b'53678' -> Almería, España
# b'53683' -> Barcelona, España
# b'53693' -> A Coruña, La Coruña, España
# b'53715' -> Extremadura, España
# b'53746' -> La Selva agreste y espesa
# b'53758' -> New York, NY, United States
# b'53766' -> Aguascalientes, México
# b'53824' -> Barcelona, España
# b'53825' -> Murcia, España
# b'53831' -> San Feliu de Guíxols, Girona, España
# b'53833' -> Barcelona, España
# b'53864' -> Madrid, España
# b'53921' -> Buenos Aires, Argentina
# b'53923' -> Corrientes, Argentina
# b'53948' -> Valencia, España
# b'53951' -> Madrid, España
# b'53953' -> Miami, Florida, Estados Unidos
# b'5396' -> Fremont, CA, United States
# b'54' -> Raleigh, NC, United States
# b'54044' -> West Korea
# b'54062' -> Madrid, España
# b'5408' -> Girona, Espanya
# b'5412' -> Madrid, España
# b'54129' -> Rafael Castillo, Buenos Aires, Argentina
# b'54137' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'54179' -> Buenos Aires, Argentina
# b'5418' -> Madrid, España
# b'54182' -> La Plata, Buenos Aires Province, Argentina
# b'54223' -> Ciudad de La Paz 1965, Buenos Aires, Argentina
# b'54331' -> Linares, España
# b'54344' -> Barcelona, España
# b'5438' -> Madrid, España
# b'54398' -> Cantabria, España
# b'54414' -> España
# b'54458' -> Castellón, España
# b'54465' -> Madrid, España
# b'54469' -> Madrid, España
# b'54471' -> Buenos Aires, Argentina
# b'54473' -> Sevilla, España
# b'54485' -> Ituzaingó, Buenos Aires, Argentina
# b'54584' -> Barcelona, España
# b'54585' -> Catalonia, Espanya
# b'54587' -> Toledo, España
# b'54589' -> Almería, España
# b'54638' -> Buenos Aires, Argentina
# b'54717' -> Buenos Aires, Argentina
# b'54729' -> Barcelona, España
# b'54733' -> Beasáin, Guipúzcoa, España
# b'5475' -> Vigo, España
# b'54852' -> Sevilla, España
# b'54860' -> Tarrasa, España
# b'54893' -> Barcelona, España
# b'54899' -> Madrid, España
# b'54949' -> Cádiz, España
# b'54980' -> Barcelona, España
# b'54981' -> Bilbao, España
# b'54982' -> Barcelona, España
# b'55029' -> Corrientes, Argentina
# b'55038' -> Seattle, WA, United States
# b'55052' -> España
# b'55065' -> Granada, España
# b'55074' -> Miami, Florida, Estados Unidos
# b'55122' -> Buenos Aires, Argentina
# b'55171' -> Madrid, España
# b'55188' -> Mérida, Badajoz, España
# b'55234' -> España
# b'55235' -> Valladolid, España
# b'55248' -> España
# b'55264' -> España
# b'55301' -> Aguascalientes, México
# b'55335' -> Valencia, España
# b'55352' -> Barcelona, España
# b'55431' -> Madrid, España
# b'55471' -> Burgos, España
# b'55590' -> Madrid, España
# b'55593' -> Sevilla, España
# b'55600' -> Barcelona, España
# b'5561' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'55616' -> Barcelona, España
# b'55623' -> Alaquàs, Valencia, España
# b'55655' -> Palermo, Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'55675' -> Corrientes, Argentina
# b'55686' -> Manizales, Colombia
# b'55732' -> Corrientes, Argentina
# b'55880' -> Buenos Aires, Argentina
# b'55888' -> Barcelona, España
# b'55923' -> Puerto Real, España
# b'5594' -> Madrid, España
# b'55940' -> Madrid, España
# b'56008' -> Madrid, España
# b'5612' -> Buenos Aires, Argentina
# b'56121' -> Valencia, España
# b'56124' -> Morón, Buenos Aires, Argentina
# b'56171' -> Buenos Aires, Argentina
# b'56198' -> Buenos Aires, Argentina
# b'562' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'56206' -> La Plata, Buenos Aires, Argentina
# b'56229' -> Barcelona, España
# b'56235' -> Oiartzun, Guipúzcoa, España
# b'56254' -> Chipiona, Cádiz, España
# b'56255' -> Alicante, España
# b'5630' -> Madrid, España
# b'5632' -> Pamplona, Navarra, España
# b'56357' -> España
# b'56394' -> Valladolid, España
# b'56400' -> New York, NY, United States
# b'5642' -> Buenos Aires, Argentina
# b'56481' -> Tenerife, Santa Cruz de Tenerife, España
# b'56483' -> Tenerife, Santa Cruz de Tenerife, España
# b'56492' -> Vigo, Pontevedra, España
# b'56530' -> Rivas-Vaciamadrid, España
# b'56552' -> Florida, United States
# b'56566' -> Sevilla, España
# b'56613' -> Madrid, España
# b'56615' -> Málaga, España
# b'56677' -> Buenos Aires, Argentina
# b'5669' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'56697' -> Mar del Plata, Buenos Aires, Argentina
# b'56699' -> Tenerife, Santa Cruz de Tenerife, Canary Islands, España
# b'5674' -> Madrid, España
# b'56752' -> Madrid, España
# b'56758' -> Teruel, España
# b'56762' -> Redondela, Pontevedra, España
# b'56796' -> Buenos Aires
# b'56840' -> Buenos Aires, Argentina
# b'5685' -> Bilbao, Vizcaya, España
# b'56865' -> España
# b'56866' -> Zaragoza, España
# b'56973' -> Buenos Aires, Argentina
# b'5703' -> Aguascalientes, México
# b'57037' -> Barcelona, España
# b'57046' -> Madrid, España
# b'57052' -> España
# b'57063' -> Cádiz, España
# b'57076' -> Madrid, España
# b'57081' -> Valencia, España
# b'57159' -> Valencia, España
# b'57243' -> Barcelona, España
# b'57316' -> Murcia, España
# b'57367' -> Manizales - Caldas, Colombia
# b'5741' -> Barcelona, España
# b'57411' -> Buenos Aires, Argentina
# b'57450' -> Ridgewood, Queens, NY, United States
# b'57453' -> Buenos Aires,Argentina
# b'57475' -> Buenos Aires, Argentina
# b'57482' -> Manizales - Caldas, Colombia
# b'5767' -> Lowestoft, United Kingdom
# b'58' -> Buenos Aires, Argentina
# b'5813' -> Málaga, España
# b'5831' -> CABA, Autonomous City of Buenos Aires, Argentina
# b'5877' -> Omaha, NE, United States
# b'5882' -> Madrid, España
# b'5922' -> Madrid, España
# b'5926' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'5929' -> Seattle, WA, United States
# b'5943' -> Nacogdoches, TX, United States
# b'5990' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'5997' -> Dolores Hidalgo Cuna de la Independencia Nacional, Guanajuato, México
# b'60' -> Mandaluyong, Philippines
# b'6039' -> Capital Federal, Ciudad Autónoma de Buenos Aires, Argentina
# b'6044' -> Buenos Aires, Argentina
# b'6095' -> Torrent, Valencia, València, España
# b'6097' -> Buenos Aires Province, Argentina
# b'61' -> Lima, Miraflores, Peru
# b'6133' -> Cantabria, España
# b'6138' -> Paso de Los Libres, Argentina
# b'6163' -> Pittsburgh, PA, United States
# b'6173' -> Barcelona, España
# b'6246' -> Barcelona, España
# b'6366' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'6377' -> Mallorca, Islas Baleares, España
# b'6387' -> Granada, España
# b'6406' -> Londres, Reino Unido
# b'6410' -> Madrid, España
# b'6415' -> Vidreres, Spain
# b'6470' -> Buenos Aires, Argentina
# b'6481' -> Valencia, España
# b'6496' -> Gijón, Asturias, España
# b'6564' -> Madrid, España
# b'6568' -> Valencia, España
# b'660' -> Buenos Aires
# b'6608' -> Barcelona, España
# b'662' -> New York, NY, United States
# b'6623' -> Valencia, España
# b'6640' -> Buenos Aires, Argentina
# b'6650' -> Madrid, España
# b'6652' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'6656' -> Madrid, España
# b'6775' -> España
# b'6786' -> Barcelona, Catalunya, Western Europe
# b'6793' -> Málaga, España
# b'68' -> Lincoln, NE, United States
# b'6815' -> Ciudad del Este, Alto Parana, Paraguay
# b'685' -> Eastern United States
# b'6897' -> Lérida, España
# b'6901' -> Itesm, Mexico
# b'6925' -> Madrid, España
# b'6939' -> United States
# b'6948' -> España
# b'6965' -> Buenos Aires, Argentina
# b'6974' -> España
# b'6977' -> San Francisco, California, Estados Unidos
# b'6999' -> Buenos Aires, Argentina
# b'7009' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'7081' -> Mieres del Camino, Spain
# b'71' -> Buenos Aires, Argentina
# b'7104' -> Castellón de la Plana, España
# b'7112' -> New Mexico, Estados Unidos
# b'7127' -> Málaga, España
# b'7131' -> Alicante, España
# b'7134' -> Brest, Francia
# b'7145' -> Madrid, España
# b'716' -> Corrientes, Argentina
# b'7178' -> Madrid, España
# b'7188' -> Madrid, España
# b'720' -> 92.96 million miles from the sun
# b'7229' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'7245' -> Valencia, España
# b'7248' -> Barcelona, España
# b'7249' -> Madrid, España
# b'7256' -> Madrid, España
# b'7274' -> Gran Canaria, Las Palmas, España
# b'7277' -> Salamanca, España
# b'7301' -> Madrid, España
# b'7308' -> Barcelona, España
# b'731' -> Aguascalientes, Mexico
# b'739' -> Coral Gables, FL, United States
# b'7400' -> Resistencia, Chaco, Argentina
# b'7424' -> Buenos Aires Province, Argentina
# b'7492' -> Madrid, España
# b'7497' -> Málaga, España
# b'7528' -> Madrid, España
# b'762' -> New York, United States
# b'7630' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'7634' -> Buenos Aires, Argentina
# b'7670' -> Buenos Aires, Argentina
# b'784' -> Buenos Aires, Argentina
# b'801' -> Eskişehir, Provincia de Eskişehir, Turquía
# b'82' -> España
# b'866' -> Los Angeles, CA
# b'8738' -> Logroño, La Rioja, España
# b'8780' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'8797' -> Pamplona, Navarra, España
# b'8816' -> Barcelona, España
# b'8841' -> Tolosa, España
# b'8860' -> Madison, Wisconsin, Estados Unidos
# b'8865' -> Barcelona, España
# b'8866' -> Miranda de Ebro, España
# b'8867' -> España
# b'8873' -> Buenos Aires, Argentina
# b'8906' -> Lanús Oeste, Buenos Aires, Argentina
# b'8907' -> Barcelona, España
# b'893' -> San Francisco, CA, United States
# b'894' -> Buenos Aires, Argentina
# b'8965' -> Hey bubs "Phonesaber Unlock" Google Play Store free no ads!
# b'8972' -> Madrid, España
# b'8976' -> Sevilla, España
# b'8983' -> Madrid, España
# b'8984' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'8989' -> Callosa d'en Sarrià, Alicante, España
# b'8995' -> España
# b'902' -> Tandil, Buenos Aires, Argentina
# b'9037' -> Buenos Aires, Argentina
# b'9050' -> Corrientes, Argentina
# b'9051' -> Buenos Aires, Argentina
# b'9085' -> Margarita Island, Nueva Esparta, Venezuela
# b'9097' -> España
# b'9156' -> Madrid, España
# b'9157' -> Cataluña, España
# b'9158' -> Sevilla, España
# b'9173' -> United States
# b'9286' -> Madrid, España
# b'9316' -> Zaragoza, España
# b'9349' -> No todo el que viaja sin rumbo está perdido
# b'9395' -> Ciudad de Buenos Aires, Argentina
# b'9452' -> Caballito, Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'9460' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina
# b'9468' -> Méntrida, Toledo, España
# b'9487' -> Barcelona, España
# b'9503' -> Genoves
# b'9509' -> Bilbao, España
# b'9549' -> Cádiz, España
# b'9569' -> Chester, United Kingdom
# b'9572' -> Buenos Aires, Argentina
# b'9587' -> Ciudad de la Costa, Canelones Department, Uruguay
# b'96' -> New York, NY, United States
# b'9633' -> Girona, Espanya
# b'9647' -> San Francisco, California, Estados Unidos
# b'9673' -> Aguascalientes, Ags.
# b'9691' -> Vigo, España
# b'9692' -> Avilés, Asturias, España
# b'9702' -> Buenos Aires, Argentina
# b'9715' -> Zaragoza, España
# b'9717' -> Buenos Aires, Argentina
# b'9748' -> Madrid, España
# b'9806' -> España
# b'9809' -> España
# b'9811' -> Ciudad Autónoma de Buenos Aires, Argentina
# b'9812' -> Buenos Aires, Ciudad Autónoma de Buenos Aires, Argentina
# b'9820' -> Santo Domingo Este, Santo Domingo, Dominican Republic
# b'9841' -> Palma de Mallorca, España
# b'9844' -> Buenos Aires, Argentina
# b'9851' -> San Francisco, CA, United States
# b'988' -> Buenos Aires
# b'9887' -> EOM | Design Group
# b'99' -> Buenos Aires, Argentina
# b'9987' -> Buenos Aires, Autonomous City of Buenos Aires, Argentina

# %% [markdown]
# ## EJERCICIO: Crear una nueva tabla `poststags` que, de forma eficiente, para cada _tag_, liste los `Id` de los posts que utilizan ese _tag_.

# %% [markdown]
# Para la realización de este ejercicio, hemos usado la estructura mostrada en la sesión 5 a la hora de crear la tabla `Links`. En este caso, se ha añadido una única familia de columnas que contiene todos los ids de los posts que utilizan un determinado tag. Para poder incluir todos los ids en esa misma familia, las diferentes columnas para cada id se han creado de la forma `Post_ID`, siendo `ID` el id del post. Además, se ha creado un filtro de Bloom de tipo `ROW`, para poder acelerar las consultas sobre las filas, estableciendo rápidamente si una fila no existe.
#
# Para rellenar la tabla se ha hecho un `scan` sobre la tabla `posts`, extrayendo únicamente la columna `rawdata:Tags`. A continuación, de igual manera que se hizo en la sesión 1, se extraen todos los tags pasándole a la función `findall` de la librería `re` una expresión regular que indica que queremos todos los elementos que estén entre los símbolos '<' y '>'. Por cada tag obtenido, se añade una columna con el id del post (la `key` que devuelve `scan`) en el que estamos.

# %%
import sys
import re

class BuildPostsTags():
    def __init__(self,connection):
        
        try:
            connection.create_table(
                "poststags",
                {
                    'posts': dict(bloom_filter_type='ROW',max_versions=1),
                })
        except:
            print ("Database poststags already exists.")
            pass

        self.table = connection.table('poststags')
        self.posts = connection.table('posts')

    def run(self):
        
        with self.table.batch(batch_size=500) as pt:
            for key, data in self.posts.scan(columns=["rawdata:Tags"]):
                postid = key.strip().decode('utf-8')
                #print("\n{0}:".format(postid))
                for tag in re.findall('<(.*?)>', data[b'rawdata:Tags'].decode('utf-8')):
                    tag = tag.strip()
                    #sys.stdout.write(".")
                    pt.put(tag, {'posts:Post_' + postid : postid})

# %% [markdown]
# Cargamos la tabla:

# %%
with hbasecon.connection() as connection:
    BuildPostsTags(connection).run()

# %% [markdown]
# A modo de ejemplo, extraemos las primeras 20 filas de la tabla aplicando un `scan` sobre la misma:

# %%
with hbasecon.connection() as connection:
    poststags = connection.table('poststags')
    
    for key, data in poststags.scan(limit=20):
        print(key, '->', data, '\n')
# Out:
# b'.asmx' -> {b'posts:Post_27967': b'27967', b'posts:Post_35663': b'35663', b'posts:Post_37980': b'37980', b'posts:Post_51037': b'51037', b'posts:Post_54439': b'54439', b'posts:Post_71488': b'71488', b'posts:Post_80504': b'80504'}
#
# b'.htaccess' -> {b'posts:Post_10428': b'10428', b'posts:Post_12944': b'12944', b'posts:Post_14104': b'14104', b'posts:Post_14444': b'14444', b'posts:Post_14611': b'14611', b'posts:Post_14740': b'14740', b'posts:Post_15220': b'15220', b'posts:Post_15280': b'15280', b'posts:Post_15352': b'15352', b'posts:Post_15586': b'15586', b'posts:Post_16168': b'16168', b'posts:Post_16562': b'16562', b'posts:Post_17113': b'17113', b'posts:Post_18294': b'18294', b'posts:Post_18463': b'18463', b'posts:Post_19880': b'19880', b'posts:Post_20212': b'20212', b'posts:Post_20910': b'20910', b'posts:Post_22102': b'22102', b'posts:Post_23062': b'23062', b'posts:Post_23359': b'23359', b'posts:Post_2578': b'2578', b'posts:Post_25931': b'25931', b'posts:Post_26869': b'26869', b'posts:Post_30337': b'30337', b'posts:Post_30768': b'30768', b'posts:Post_31300': b'31300', b'posts:Post_31322': b'31322', b'posts:Post_31625': b'31625', b'posts:Post_36380': b'36380', b'posts:Post_36797': b'36797', b'posts:Post_36925': b'36925', b'posts:Post_3929': b'3929', b'posts:Post_39605': b'39605', b'posts:Post_39837': b'39837', b'posts:Post_40685': b'40685', b'posts:Post_41667': b'41667', b'posts:Post_42297': b'42297', b'posts:Post_42916': b'42916', b'posts:Post_43005': b'43005', b'posts:Post_43013': b'43013', b'posts:Post_43594': b'43594', b'posts:Post_46014': b'46014', b'posts:Post_46091': b'46091', b'posts:Post_48269': b'48269', b'posts:Post_48529': b'48529', b'posts:Post_48552': b'48552', b'posts:Post_48593': b'48593', b'posts:Post_48761': b'48761', b'posts:Post_49530': b'49530', b'posts:Post_49692': b'49692', b'posts:Post_50063': b'50063', b'posts:Post_50298': b'50298', b'posts:Post_50962': b'50962', b'posts:Post_51694': b'51694', b'posts:Post_53591': b'53591', b'posts:Post_54310': b'54310', b'posts:Post_54366': b'54366', b'posts:Post_54393': b'54393', b'posts:Post_54983': b'54983', b'posts:Post_55209': b'55209', b'posts:Post_55627': b'55627', b'posts:Post_56230': b'56230', b'posts:Post_56550': b'56550', b'posts:Post_57584': b'57584', b'posts:Post_59193': b'59193', b'posts:Post_60167': b'60167', b'posts:Post_60834': b'60834', b'posts:Post_61511': b'61511', b'posts:Post_61816': b'61816', b'posts:Post_6213': b'6213', b'posts:Post_6260': b'6260', b'posts:Post_62653': b'62653', b'posts:Post_63183': b'63183', b'posts:Post_63819': b'63819', b'posts:Post_64172': b'64172', b'posts:Post_64761': b'64761', b'posts:Post_64986': b'64986', b'posts:Post_65017': b'65017', b'posts:Post_67622': b'67622', b'posts:Post_71594': b'71594', b'posts:Post_7261': b'7261', b'posts:Post_73973': b'73973', b'posts:Post_74570': b'74570', b'posts:Post_74762': b'74762', b'posts:Post_75267': b'75267', b'posts:Post_76017': b'76017', b'posts:Post_77481': b'77481', b'posts:Post_77984': b'77984', b'posts:Post_78520': b'78520', b'posts:Post_79314': b'79314', b'posts:Post_79481': b'79481', b'posts:Post_79771': b'79771', b'posts:Post_79870': b'79870', b'posts:Post_80383': b'80383', b'posts:Post_80741': b'80741', b'posts:Post_8204': b'8204', b'posts:Post_82546': b'82546', b'posts:Post_8286': b'8286', b'posts:Post_83211': b'83211', b'posts:Post_8560': b'8560', b'posts:Post_87210': b'87210', b'posts:Post_88102': b'88102', b'posts:Post_89865': b'89865', b'posts:Post_90157': b'90157', b'posts:Post_91308': b'91308', b'posts:Post_91656': b'91656', b'posts:Post_91782': b'91782', b'posts:Post_92157': b'92157', b'posts:Post_93331': b'93331', b'posts:Post_93437': b'93437', b'posts:Post_94384': b'94384', b'posts:Post_94453': b'94453', b'posts:Post_9508': b'9508', b'posts:Post_95838': b'95838', b'posts:Post_96650': b'96650'}
#
# b'.htpasswd' -> {b'posts:Post_79771': b'79771', b'posts:Post_8286': b'8286'}
#
# b'.net' -> {b'posts:Post_1': b'1', b'posts:Post_10170': b'10170', b'posts:Post_10192': b'10192', b'posts:Post_10355': b'10355', b'posts:Post_10502': b'10502', b'posts:Post_10989': b'10989', b'posts:Post_11178': b'11178', b'posts:Post_11390': b'11390', b'posts:Post_11506': b'11506', b'posts:Post_11740': b'11740', b'posts:Post_11793': b'11793', b'posts:Post_1204': b'1204', b'posts:Post_13243': b'13243', b'posts:Post_13287': b'13287', b'posts:Post_13320': b'13320', b'posts:Post_13526': b'13526', b'posts:Post_13915': b'13915', b'posts:Post_14227': b'14227', b'posts:Post_14622': b'14622', b'posts:Post_14666': b'14666', b'posts:Post_14678': b'14678', b'posts:Post_15292': b'15292', b'posts:Post_15498': b'15498', b'posts:Post_15547': b'15547', b'posts:Post_16317': b'16317', b'posts:Post_1650': b'1650', b'posts:Post_17132': b'17132', b'posts:Post_17167': b'17167', b'posts:Post_17214': b'17214', b'posts:Post_17271': b'17271', b'posts:Post_17632': b'17632', b'posts:Post_17703': b'17703', b'posts:Post_17774': b'17774', b'posts:Post_17894': b'17894', b'posts:Post_17898': b'17898', b'posts:Post_18198': b'18198', b'posts:Post_18477': b'18477', b'posts:Post_19716': b'19716', b'posts:Post_1977': b'1977', b'posts:Post_20134': b'20134', b'posts:Post_20427': b'20427', b'posts:Post_2046': b'2046', b'posts:Post_20716': b'20716', b'posts:Post_20784': b'20784', b'posts:Post_2080': b'2080', b'posts:Post_21296': b'21296', b'posts:Post_21421': b'21421', b'posts:Post_21456': b'21456', b'posts:Post_21555': b'21555', b'posts:Post_21669': b'21669', b'posts:Post_21859': b'21859', b'posts:Post_22409': b'22409', b'posts:Post_23056': b'23056', b'posts:Post_23268': b'23268', b'posts:Post_23456': b'23456', b'posts:Post_23535': b'23535', b'posts:Post_23811': b'23811', b'posts:Post_23821': b'23821', b'posts:Post_23846': b'23846', b'posts:Post_23920': b'23920', b'posts:Post_24423': b'24423', b'posts:Post_24683': b'24683', b'posts:Post_24755': b'24755', b'posts:Post_24925': b'24925', b'posts:Post_25271': b'25271', b'posts:Post_25275': b'25275', b'posts:Post_25312': b'25312', b'posts:Post_254': b'254', b'posts:Post_25597': b'25597', b'posts:Post_25800': b'25800', b'posts:Post_25812': b'25812', b'posts:Post_25999': b'25999', b'posts:Post_26010': b'26010', b'posts:Post_26060': b'26060', b'posts:Post_26394': b'26394', b'posts:Post_26433': b'26433', b'posts:Post_26823': b'26823', b'posts:Post_27202': b'27202', b'posts:Post_28236': b'28236', b'posts:Post_29702': b'29702', b'posts:Post_2973': b'2973', b'posts:Post_29998': b'29998', b'posts:Post_30408': b'30408', b'posts:Post_31016': b'31016', b'posts:Post_31283': b'31283', b'posts:Post_31750': b'31750', b'posts:Post_31863': b'31863', b'posts:Post_3207': b'3207', b'posts:Post_3219': b'3219', b'posts:Post_32225': b'32225', b'posts:Post_32245': b'32245', b'posts:Post_32323': b'32323', b'posts:Post_32380': b'32380', b'posts:Post_32411': b'32411', b'posts:Post_3253': b'3253', b'posts:Post_32608': b'32608', b'posts:Post_33246': b'33246', b'posts:Post_33277': b'33277', b'posts:Post_33672': b'33672', b'posts:Post_34183': b'34183', b'posts:Post_34252': b'34252', b'posts:Post_3459': b'3459', b'posts:Post_34612': b'34612', b'posts:Post_3490': b'3490', b'posts:Post_35274': b'35274', b'posts:Post_35297': b'35297', b'posts:Post_35677': b'35677', b'posts:Post_36015': b'36015', b'posts:Post_36143': b'36143', b'posts:Post_36218': b'36218', b'posts:Post_3694': b'3694', b'posts:Post_3784': b'3784', b'posts:Post_38289': b'38289', b'posts:Post_3867': b'3867', b'posts:Post_38762': b'38762', b'posts:Post_39763': b'39763', b'posts:Post_40147': b'40147', b'posts:Post_40571': b'40571', b'posts:Post_40701': b'40701', b'posts:Post_40773': b'40773', b'posts:Post_41187': b'41187', b'posts:Post_41370': b'41370', b'posts:Post_42229': b'42229', b'posts:Post_42237': b'42237', b'posts:Post_42512': b'42512', b'posts:Post_4409': b'4409', b'posts:Post_4419': b'4419', b'posts:Post_4443': b'4443', b'posts:Post_44654': b'44654', b'posts:Post_45728': b'45728', b'po ...
#
# b'.net-core' -> {b'posts:Post_96125': b'96125', b'posts:Post_96244': b'96244'}
#
# b'2d' -> {b'posts:Post_1789': b'1789', b'posts:Post_22357': b'22357', b'posts:Post_44073': b'44073', b'posts:Post_65443': b'65443', b'posts:Post_65484': b'65484', b'posts:Post_76996': b'76996'}
#
# b'3d' -> {b'posts:Post_278': b'278', b'posts:Post_3186': b'3186', b'posts:Post_33994': b'33994', b'posts:Post_36143': b'36143', b'posts:Post_70541': b'70541', b'posts:Post_72081': b'72081', b'posts:Post_73346': b'73346', b'posts:Post_75172': b'75172', b'posts:Post_75881': b'75881', b'posts:Post_90994': b'90994'}
#
# b'abap' -> {b'posts:Post_1017': b'1017', b'posts:Post_30995': b'30995'}
#
# b'accesibilidad' -> {b'posts:Post_24819': b'24819', b'posts:Post_33249': b'33249', b'posts:Post_77699': b'77699'}
#
# b'access-control' -> {b'posts:Post_70986': b'70986'}
#
# b'accordion' -> {b'posts:Post_15594': b'15594', b'posts:Post_30291': b'30291', b'posts:Post_44214': b'44214', b'posts:Post_65707': b'65707', b'posts:Post_75796': b'75796', b'posts:Post_77297': b'77297', b'posts:Post_97156': b'97156'}
#
# b'actionbar' -> {b'posts:Post_32041': b'32041', b'posts:Post_34777': b'34777', b'posts:Post_39759': b'39759', b'posts:Post_39770': b'39770', b'posts:Post_40602': b'40602', b'posts:Post_40919': b'40919', b'posts:Post_42817': b'42817', b'posts:Post_46433': b'46433', b'posts:Post_61088': b'61088', b'posts:Post_61351': b'61351'}
#
# b'actionscript' -> {b'posts:Post_65740': b'65740', b'posts:Post_65967': b'65967', b'posts:Post_70677': b'70677', b'posts:Post_95552': b'95552'}
#
# b'activerecord' -> {b'posts:Post_61358': b'61358', b'posts:Post_79780': b'79780', b'posts:Post_81277': b'81277', b'posts:Post_85802': b'85802', b'posts:Post_91061': b'91061', b'posts:Post_92096': b'92096', b'posts:Post_92283': b'92283'}
#
# b'activity' -> {b'posts:Post_34424': b'34424', b'posts:Post_35243': b'35243', b'posts:Post_35729': b'35729', b'posts:Post_36252': b'36252', b'posts:Post_40834': b'40834', b'posts:Post_42370': b'42370', b'posts:Post_45939': b'45939', b'posts:Post_48256': b'48256', b'posts:Post_48737': b'48737', b'posts:Post_50220': b'50220', b'posts:Post_51503': b'51503', b'posts:Post_52476': b'52476', b'posts:Post_54065': b'54065', b'posts:Post_54084': b'54084', b'posts:Post_55300': b'55300', b'posts:Post_56884': b'56884', b'posts:Post_56984': b'56984', b'posts:Post_57814': b'57814', b'posts:Post_63054': b'63054', b'posts:Post_63604': b'63604', b'posts:Post_64996': b'64996', b'posts:Post_65711': b'65711', b'posts:Post_65816': b'65816', b'posts:Post_68637': b'68637', b'posts:Post_68848': b'68848', b'posts:Post_71643': b'71643', b'posts:Post_71900': b'71900', b'posts:Post_72499': b'72499', b'posts:Post_79247': b'79247', b'posts:Post_80161': b'80161', b'posts:Post_80252': b'80252', b'posts:Post_83115': b'83115', b'posts:Post_86879': b'86879', b'posts:Post_87034': b'87034', b'posts:Post_87293': b'87293', b'posts:Post_91117': b'91117', b'posts:Post_91200': b'91200', b'posts:Post_94538': b'94538', b'posts:Post_94717': b'94717', b'posts:Post_94856': b'94856'}
#
# b'ada' -> {b'posts:Post_22506': b'22506', b'posts:Post_81330': b'81330'}
#
# b'adapter' -> {b'posts:Post_51005': b'51005', b'posts:Post_55290': b'55290', b'posts:Post_55700': b'55700', b'posts:Post_56004': b'56004', b'posts:Post_57197': b'57197', b'posts:Post_59302': b'59302', b'posts:Post_70531': b'70531', b'posts:Post_83762': b'83762', b'posts:Post_96442': b'96442'}
#
# b'adb' -> {b'posts:Post_34642': b'34642', b'posts:Post_55722': b'55722', b'posts:Post_66684': b'66684', b'posts:Post_76022': b'76022', b'posts:Post_84061': b'84061', b'posts:Post_93563': b'93563'}
#
# b'adfs' -> {b'posts:Post_27008': b'27008', b'posts:Post_483': b'483'}
#
# b'administraci\xc3\xb3n-de-software' -> {b'posts:Post_84010': b'84010', b'posts:Post_96535': b'96535'}

# %% [markdown]
# ## EJERCICIO: Construya una tabla (de la forma más eficiente) que sirva para, dados un ID de usuario que pregunta y un ID de otro usuario que responde, se pueda decir (en orden constante) si forman una pareja al estilo de la RQ4. Con esa tabla, responder a la RQ4.

# %% [markdown]
# Para la realización del último ejercicio, creamos una tabla `users_qa` que sigue de nuevo la misma estructura que en el caso anterior. Las filas de esta tabla tendrán como clave un usuario que ha hecho como mínimo una pregunta, y como columnas todos los usuarios que le han respondido. Para incluir todos esos usuarios que responden en una misma familia de columnas `answerers`, se ha seguido la misma estrategia que en el caso anterior, llamando a las columnas de la forma `answerers:User_ID`, siendo `ID` el id del usuario que responde. Además, se ha incluido también un filtro de Bloom de tipo `ROW`.
#
# Para rellenar la tabla, se ha hecho un `scan` sobre la tabla `posts`, añadiendo un filtro sobre las columnas para que solo nos devuelva aquellos `posts` que son respuestas. Esto se podría haber realizado sin añadir ningún filtro al `scan` y poniendo una sentencia `if()` que hiciera que solo se ejecutara el código del bucle para las respuestas, pero nos ha parecido más eficiente la primera opción, tras realizar varias ejecuciones.
#
# El hecho de seleccionar únicamente las respuestas se debe a que permiten obtener la pregunta a la que se refieren (usando el `ParentId`), y una vez se tiene se puede extraer en orden constante cuál es el usuario que realizó la pregunta, usando una consulta `row`. Una vez obtenidos tanto el usuario que pregunta como el que responde, si ambos son distintos, y ninguno de ellos es vacío, se añade una nueva columna con el usuario que responde a la fila correspondiente al usuario que pregunta. La comprobación de que ambos usuarios sean no vacíos se debe a que hay muchos valores de la columna `rawdata:OwnerUserId` que lo son, y que si no se eliminan causan un error en la creación de la tabla.

# %%
class BuildQA():
    def __init__(self,connection):
        
        try:
            connection.create_table(
                "users_qa",
                {
                    'answerers': dict(bloom_filter_type='ROW',max_versions=1),
                })
        except:
            print ("Database users_qa already exists.")
            pass

        self.table = connection.table('users_qa')
        self.posts = connection.table('posts')

    def run(self):
        
        with self.table.batch(batch_size=500) as qa:

            for key, data in self.posts.scan(filter="SingleColumnValueFilter('rawdata','PostTypeId', =, 'binary:2')"):
                questioner = self.posts.row(data[b'rawdata:ParentId'], columns=[b'rawdata:OwnerUserId'])
                questioner = questioner[b'rawdata:OwnerUserId'].strip().decode('utf-8')
                answerer = data[b'rawdata:OwnerUserId'].strip().decode('utf-8')
                if questioner != answerer and questioner != "" and answerer != "":
                    qa.put(questioner, {'answerers:User_' + answerer : answerer})

# %% [markdown]
# Cargamos la tabla:

# %%
with hbasecon.connection() as connection:
    BuildQA(connection).run()

# %% [markdown]
# A continuación mostramos un ejemplo de consulta en la que, dados un usuario que pregunta y otro que responde, se obtiene si son una pareja al estilo de la RQ4. Dado que una consulta `row` se ejecuta en orden constante, hacer dos de ellas también lo es, por lo que se puede determinar si ambos son recíprocos en tiempo constante.

# %%
with hbasecon.connection() as connection:
    users_qa = connection.table('users_qa')
    
    user1 = b'24'
    user2 = b'301'
    if(users_qa.row(user1, columns=['answerers:User_'+user2.decode('utf-8')]) and 
       users_qa.row(user2, columns=['answerers:User_'+user1.decode('utf-8')])):
        print('Los usuarios', user1, 'y', user2, 'son recíprocos.')
# Out:
# Los usuarios b'24' y b'301' son recíprocos.

# %% [markdown]
# Por último, vamos a responder a la RQ4 usando la tabla `users_qa`. Para ello, realizamos un `scan` sobre la misma y se comprueba (usando un `row`), para cada columna de la fila, si existe una entrada en la tabla con el id del usuario que responde como clave y el el id del usuario que pregunta como columna. En ese caso, se añaden los ids de ambos usuarios a una lista de tuplas de `python`.
#
# Además, para que no nos salgan valores repetidos, se ha añadido también la condición de que el id de uno de los usuarios sea menor que el otro.

# %%
with hbasecon.connection() as connection:
    users_qa = connection.table('users_qa')
    RQ4 = []
    for key, data in users_qa.scan():
        for elem in data:
            if (int(data[elem].decode('utf-8')) < int(key.decode('utf-8')) and 
                users_qa.row(data[elem], columns=['answerers:User_'+key.decode('utf-8')])):
                RQ4.append((data[elem],key))

# %% [markdown]
# A continuación vemos los 116 resultados devueltos por la consulta RQ4, ordenados por id del primer usuario, y después por id del segundo:

# %%
print(len(RQ4))
sorted(RQ4, key=lambda tup: (int(tup[0].decode('utf-8')), int(tup[1].decode('utf-8'))))
# Out:
# 116
# [(b'21', b'1184'),
#  (b'22', b'288'),
#  (b'22', b'342'),
#  (b'22', b'729'),
#  (b'23', b'25'),
#  (b'24', b'25'),
#  (b'24', b'95'),
#  (b'24', b'301'),
#  (b'24', b'463'),
#  (b'24', b'2230'),
#  (b'24', b'19610'),
#  (b'25', b'225'),
#  (b'25', b'288'),
#  (b'34', b'250'),
#  (b'65', b'78'),
#  (b'65', b'1184'),
#  (b'65', b'7661'),
#  (b'65', b'13558'),
#  (b'73', b'250'),
#  (b'73', b'2224'),
#  (b'73', b'6497'),
#  (b'73', b'9897'),
#  (b'73', b'29967'),
#  (b'78', b'250'),
#  (b'83', b'100'),
#  (b'83', b'301'),
#  (b'83', b'29967'),
#  (b'95', b'29967'),
#  (b'100', b'187'),
#  (b'100', b'353'),
#  (b'100', b'399'),
#  (b'100', b'529'),
#  (b'100', b'638'),
#  (b'100', b'729'),
#  (b'100', b'2004'),
#  (b'100', b'2838'),
#  (b'120', b'531'),
#  (b'154', b'13938'),
#  (b'191', b'2230'),
#  (b'227', b'342'),
#  (b'227', b'400'),
#  (b'227', b'2004'),
#  (b'250', b'399'),
#  (b'250', b'729'),
#  (b'250', b'731'),
#  (b'250', b'2163'),
#  (b'250', b'2230'),
#  (b'250', b'2429'),
#  (b'250', b'6491'),
#  (b'250', b'9897'),
#  (b'250', b'10576'),
#  (b'250', b'12625'),
#  (b'250', b'13558'),
#  (b'250', b'13938'),
#  (b'250', b'14243'),
#  (b'250', b'18597'),
#  (b'250', b'19610'),
#  (b'250', b'27881'),
#  (b'250', b'29967'),
#  (b'301', b'2230'),
#  (b'342', b'517'),
#  (b'342', b'2367'),
#  (b'398', b'547'),
#  (b'398', b'2171'),
#  (b'399', b'555'),
#  (b'463', b'801'),
#  (b'463', b'2742'),
#  (b'463', b'19600'),
#  (b'517', b'2676'),
#  (b'535', b'2230'),
#  (b'638', b'29967'),
#  (b'638', b'35232'),
#  (b'729', b'1798'),
#  (b'729', b'1839'),
#  (b'729', b'2224'),
#  (b'2004', b'2747'),
#  (b'2163', b'2230'),
#  (b'2230', b'4684'),
#  (b'2230', b'12446'),
#  (b'2230', b'16108'),
#  (b'2230', b'22112'),
#  (b'2366', b'5324'),
#  (b'2429', b'15514'),
#  (b'2832', b'6497'),
#  (b'3275', b'35873'),
#  (b'3440', b'6491'),
#  (b'5808', b'21775'),
#  (b'6095', b'13938'),
#  (b'6491', b'10576'),
#  (b'6491', b'18771'),
#  (b'6491', b'23233'),
#  (b'6491', b'29967'),
#  (b'6491', b'34430'),
#  (b'6974', b'29967'),
#  (b'9874', b'19919'),
#  (b'13558', b'13938'),
#  (b'13735', b'14088'),
#  (b'13883', b'14699'),
#  (b'13938', b'18771'),
#  (b'13938', b'19919'),
#  (b'15855', b'18124'),
#  (b'16349', b'25360'),
#  (b'16349', b'25555'),
#  (b'18376', b'26302'),
#  (b'18771', b'27881'),
#  (b'18771', b'29967'),
#  (b'20709', b'29967'),
#  (b'22112', b'29967'),
#  (b'24137', b'38468'),
#  (b'28050', b'30751'),
#  (b'29967', b'32268'),
#  (b'29967', b'39259'),
#  (b'30877', b'31132'),
#  (b'34270', b'46823'),
#  (b'44942', b'44946'),
#  (b'48306', b'55380')]
